# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
wt_conn = pd.read_csv('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/paper/connectivities/ELLeafsmoothsummarysurface_leafsource_summarytarget_v3/elsummarymodel_leafsource_summarytarget_wt_v3.csv', index_col = [0],  header=[0, 1])

Ntsr1_conn = pd.read_csv('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/paper/connectivities/ELLeafsmoothsummarysurface_leafsource_summarytarget_v3/elsummarymodel_leafsource_summarytarget_ntsr1_v3.csv', index_col = [0],  header=[0, 1])
Cux2_conn = pd.read_csv('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/paper/connectivities/ELLeafsmoothsummarysurface_leafsource_summarytarget_v3/elsummarymodel_leafsource_summarytarget_cux2_v3.csv', index_col = [0],  header=[0, 1])
Rbp4_conn = pd.read_csv('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/paper/connectivities/ELLeafsmoothsummarysurface_leafsource_summarytarget_v3/elsummarymodel_leafsource_summarytarget_rbp4_v3.csv', index_col = [0],  header=[0, 1])
Tlx3_conn = pd.read_csv('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/paper/connectivities/ELLeafsmoothsummarysurface_leafsource_summarytarget_v3/elsummarymodel_leafsource_summarytarget_tlx3_v3.csv', index_col = [0],  header=[0, 1])

# %%
wt_conn.iloc[0].sum()
# Out:
# 1.6042260864541158

# %%
import numpy as np

# %%
source_regions = np.asarray(['VISp2/3', 'VISp4', 'VISp5', 'VISp6a','VISl4', 'VISl5', 'VISl6a'])
target_regions = [(  'ipsi',     'LGv'), (  'ipsi',     'LGd'),(  'ipsi',     'VISp'), (  'ipsi',     'VISl')]
targ_reg = [(  'ipsi',     'ORBvl'), (  'ipsi',     'AId'),(  'ipsi',     'AIv'), (  'ipsi',     'TEa'),
            (  'ipsi',     'ECT'), (  'ipsi',     'BLA'),(  'ipsi',     'CEA')]
#            '','','','','','','', 'ORBvl.1','AId.1','AIv.1','TEa.1','ECT.1','BLA.1','CEA.1' ])

#target_regions = np.asarray(['LGv','LGd','VISp','VISl'])
#targ_reg = np.asarray(['ORBvl','AId','AIv','PTLp','TEa','ECT','BLAa','CEA', 'ORBvl.1','AId.1','AIv.1','PTLp.1','TEa.1','ECT.1','BLAa.1','CEA.1' ])
#source_reg = np.asarray(['MOp2/3', 'MOp5', 'MOp6a','MOs2/3', 'MOs5', 'MOs6a' ])
#targ_reg = np.asarray(['ORBvl','AId','AIv','TEa','ECT','BLA','CEA', 'ORBvl.1','AId.1','AIv.1','TEa.1','ECT.1','BLA.1','CEA.1' ])
source_reg = np.asarray(['MOp2/3', 'MOp5', 'MOp6a','MOs2/3', 'MOs5', 'MOs6a' ])

# %%
fig, axes = plt.subplots(2,5, figsize = (30,10))
cbar_ax = fig.add_axes([.91, .3, .03, .4])

tp = np.log(wt_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,0], cbar = False)

tp = np.log(wt_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,0], cbar = False)

tp = np.log(Cux2_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,1], cbar = False)

tp = np.log(Cux2_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,1], cbar = False)

tp = np.log(Ntsr1_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,2], cbar = False)

tp = np.log(Ntsr1_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,2], cbar = False)

tp = np.log(Rbp4_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,3], cbar = False)

tp = np.log(Rbp4_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,3], cbar = False)

tp = np.log(Tlx3_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,4], cbar = False)

tp = np.log(Tlx3_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,4], cbar = True,cbar_ax= cbar_ax) #cbar_kws={'label': 'Log projection strength'})
cbar_ax.set_title('Log(Connection Strength)', fontsize = 20)

axes[0,0].set_title('Wild-type (C57BL/6J)', fontsize = 20)
axes[0,1].set_title('Cux2-IRES-Cre_PL', fontsize = 20)
axes[0,2].set_title('Ntsr1-Cre_GN220', fontsize = 20)
axes[0,3].set_title('Rbp4-Cre_KL100', fontsize = 20)
axes[0,4].set_title('Tlx3-Cre_PL56', fontsize = 20)

axes[1,0].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,1].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,2].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,3].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,4].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)

axes[1,0].set_ylabel('MOp/MOs Sources', fontsize = 20)
axes[0,0].set_ylabel('VISp/VISl Sources', fontsize = 20)

axes[1,1].set_ylabel('')
axes[0,1].set_ylabel('')

axes[1,2].set_ylabel('')
axes[0,2].set_ylabel('')

axes[1,3].set_ylabel('')
axes[0,3].set_ylabel('')

axes[1,4].set_ylabel('')
axes[0,4].set_ylabel('')

axes[1,0].set_xlabel('', fontsize = 20)
axes[0,0].set_xlabel('', fontsize = 20)

axes[1,1].set_xlabel('')
axes[0,1].set_xlabel('')

axes[1,2].set_xlabel('Targets', fontsize = 20)
axes[0,2].set_xlabel('', fontsize = 20)

axes[1,3].set_xlabel('')
axes[0,3].set_xlabel('')

axes[1,4].set_xlabel('')
axes[0,4].set_xlabel('')
#plt.savefig('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/visp_mo_1201')

# %%
fig, axes = plt.subplots(2,5, figsize = (30,10))
cbar_ax = fig.add_axes([.91, .3, .03, .4])

#tp = np.log(wt_conn.loc[source_regions].loc[:,target_regions])
#tp.iloc[np.where(tp < -9)] = -9
vmin_vis = 0.
vmax_vis = 1.
vmin_mos = 0.
vmax_mos = .001

sns.heatmap(wt_conn.loc[source_regions].loc[:,target_regions], vmin = vmin_vis, vmax = vmax_vis, ax= axes[0,0], cbar = False)

#tp = np.log(wt_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(wt_conn.loc[source_reg].loc[:,targ_reg],vmin = vmin_mos, vmax = vmax_mos, ax= axes[1,0], cbar = False)

#tp = np.log(Cux2_conn.loc[source_regions].loc[:,target_regions])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Cux2_conn.loc[source_reg].loc[:,target_regions], vmin = vmin_vis, vmax = vmax_vis, ax= axes[0,1], cbar = False)

#tp = np.log(Cux2_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Cux2_conn.loc[source_reg].loc[:,targ_reg], vmin = vmin_mos, vmax = vmax_mos, ax= axes[1,1], cbar = False)

#tp = np.log(Ntsr1_conn.loc[source_regions].loc[:,target_regions])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Ntsr1_conn.loc[source_regions].loc[:,target_regions], vmin = vmin_vis, vmax = vmax_vis,ax= axes[0,2], cbar = False)

#tp = np.log(Ntsr1_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Ntsr1_conn.loc[source_reg].loc[:,targ_reg],vmin = vmin_mos, vmax = vmax_mos,  ax= axes[1,2], cbar = False)

#tp = np.log(Rbp4_conn.loc[source_regions].loc[:,target_regions])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Rbp4_conn.loc[source_regions].loc[:,target_regions], vmin = vmin_vis, vmax = vmax_vis, ax= axes[0,3], cbar = False)

#tp = np.log(Rbp4_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Rbp4_conn.loc[source_reg].loc[:,targ_reg],vmin = vmin_mos, vmax = vmax_mos,  ax= axes[1,3], cbar = False)

#tp = Tlx3_conn.loc[source_regions].loc[:,target_regions]
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Tlx3_conn.loc[source_regions].loc[:,target_regions],vmin = vmin_vis, vmax = vmax_vis,  ax= axes[0,4], cbar = False)

#tp = np.log(Tlx3_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Tlx3_conn.loc[source_reg].loc[:,targ_reg], ax= axes[1,4],vmin = vmin_mos, vmax = vmax_mos, cbar = True,cbar_ax= cbar_ax) #cbar_kws={'label': 'Log projection strength'})
cbar_ax.set_title('Log(Connection Strength)', fontsize = 20)

axes[0,0].set_title('Wild-type (C57BL/6J)', fontsize = 20)
axes[0,1].set_title('Cux2-IRES-Cre_PL', fontsize = 20)
axes[0,2].set_title('Ntsr1-Cre_GN220', fontsize = 20)
axes[0,3].set_title('Rbp4-Cre_KL100', fontsize = 20)
axes[0,4].set_title('Tlx3-Cre_PL56', fontsize = 20)

axes[1,0].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,1].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,2].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,3].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,4].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)

axes[1,0].set_ylabel('MOp/MOs Sources', fontsize = 20)
axes[0,0].set_ylabel('VISp/VISl Sources', fontsize = 20)

axes[1,1].set_ylabel('')
axes[0,1].set_ylabel('')

axes[1,2].set_ylabel('')
axes[0,2].set_ylabel('')

axes[1,3].set_ylabel('')
axes[0,3].set_ylabel('')

axes[1,4].set_ylabel('')
axes[0,4].set_ylabel('')

axes[1,0].set_xlabel('', fontsize = 20)
axes[0,0].set_xlabel('', fontsize = 20)

axes[1,1].set_xlabel('')
axes[0,1].set_xlabel('')

axes[1,2].set_xlabel('Targets', fontsize = 20)
axes[0,2].set_xlabel('', fontsize = 20)

axes[1,3].set_xlabel('')
axes[0,3].set_xlabel('')

axes[1,4].set_xlabel('')
axes[0,4].set_xlabel('')
#plt.savefig('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/visp_mo_1201')

# %%
source_reg = np.asarray(['MOs5', 'MOs6a' ])

# %%
# %matplotlib inline
sns.heatmap(wt_conn.loc[source_reg].loc[:,targ_reg], cbar = False)

# %%
fig, axes = plt.subplots(2,5, figsize = (30,10))
cbar_ax = fig.add_axes([.91, .3, .03, .4])

#tp = np.log(wt_conn.loc[source_regions].loc[:,target_regions])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(wt_conn.loc[source_regions].loc[:,target_regions],  ax= axes[0,0], cbar = False)

#tp = np.log(wt_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(wt_conn.loc[source_reg].loc[:,targ_reg], ax= axes[1,0], cbar = False)

#tp = np.log(Cux2_conn.loc[source_regions].loc[:,target_regions])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Cux2_conn.loc[source_reg].loc[:,target_regions],  ax= axes[0,1], cbar = False)

#tp = np.log(Cux2_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Cux2_conn.loc[source_reg].loc[:,targ_reg],  ax= axes[1,1], cbar = False)

#tp = np.log(Ntsr1_conn.loc[source_regions].loc[:,target_regions])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Ntsr1_conn.loc[source_regions].loc[:,target_regions], ax= axes[0,2], cbar = False)

#tp = np.log(Ntsr1_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Ntsr1_conn.loc[source_reg].loc[:,targ_reg],  ax= axes[1,2], cbar = False)

#tp = np.log(Rbp4_conn.loc[source_regions].loc[:,target_regions])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Rbp4_conn.loc[source_regions].loc[:,target_regions],  ax= axes[0,3], cbar = False)

#tp = np.log(Rbp4_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Rbp4_conn.loc[source_reg].loc[:,targ_reg],  ax= axes[1,3], cbar = False)

#tp = Tlx3_conn.loc[source_regions].loc[:,target_regions]
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Tlx3_conn.loc[source_regions].loc[:,target_regions],  ax= axes[0,4], cbar = False)

#tp = np.log(Tlx3_conn.loc[source_reg].loc[:,targ_reg])
#tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(Tlx3_conn.loc[source_reg].loc[:,targ_reg], ax= axes[1,4], cbar = True,cbar_ax= cbar_ax) #cbar_kws={'label': 'Log projection strength'})
cbar_ax.set_title('Log(Connection Strength)', fontsize = 20)

axes[0,0].set_title('Wild-type (C57BL/6J)', fontsize = 20)
axes[0,1].set_title('Cux2-IRES-Cre_PL', fontsize = 20)
axes[0,2].set_title('Ntsr1-Cre_GN220', fontsize = 20)
axes[0,3].set_title('Rbp4-Cre_KL100', fontsize = 20)
axes[0,4].set_title('Tlx3-Cre_PL56', fontsize = 20)

axes[1,0].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,1].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,2].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,3].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,4].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)

axes[1,0].set_ylabel('MOp/MOs Sources', fontsize = 20)
axes[0,0].set_ylabel('VISp/VISl Sources', fontsize = 20)

axes[1,1].set_ylabel('')
axes[0,1].set_ylabel('')

axes[1,2].set_ylabel('')
axes[0,2].set_ylabel('')

axes[1,3].set_ylabel('')
axes[0,3].set_ylabel('')

axes[1,4].set_ylabel('')
axes[0,4].set_ylabel('')

axes[1,0].set_xlabel('', fontsize = 20)
axes[0,0].set_xlabel('', fontsize = 20)

axes[1,1].set_xlabel('')
axes[0,1].set_xlabel('')

axes[1,2].set_xlabel('Targets', fontsize = 20)
axes[0,2].set_xlabel('', fontsize = 20)

axes[1,3].set_xlabel('')
axes[0,3].set_xlabel('')

axes[1,4].set_xlabel('')
axes[0,4].set_xlabel('')
#plt.savefig('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/visp_mo_1201')
# Out:
# Text(0.5, 365.50909090909096, '')

# %%
# srs = np.asarray(['VISp1', 'VISp2/3', 'VISp4', 'VISp5', 'VISp6a', 'VISp6b'])
# trs = np.asarray(['VISp1', 'VISp2/3' ,'VISp4', 'VISp5' ,'VISp6a','VISp6b','LGd-sh', 'LGd-co', 'LGd-ip','VISam1','VISam2/3','VISam4','VISam5', 'VISam6a'])

# fig, axes = plt.subplots(figsize = (30,10))
# sns.heatmap(wt_conn.loc[srs].loc[:,trs])

# %%
target_regions = [(  'ipsi',     'LGv'), (  'ipsi',     'LGd'),(  'ipsi',     'VISp'), (  'ipsi',     'VISl')]

# %%
sns.heatmap(wt_conn.loc[srs].loc[:,target_regions])

# %%
wt_conn.index
# Out:
# Index(['ICc', 'ICd', 'ICe', 'PSV', 'IF', 'PT', 'IG', 'AAA', 'IGL', 'PVa',
#        ...
#        'IntG', 'VMPO', 'PeF', 'HATA', 'Pa5', 'VeCB', 'SCO', 'PDTg', 'Pa4',
#        'PN'],
#       dtype='object', name='TMv', length=563)

# %%
wt_conn = pd.read_csv('/Users/samsonkoelle/Downloads/connectivities_ELLeafsmooth_leafsource_summarytarget/wt_leafsmooth_leafsurface_sumtarget_1201.csv', index_col = [0],  header=[0, 1])

Ntsr1_conn = pd.read_csv('/Users/samsonkoelle/Downloads/connectivities_ELLeafsmooth_leafsource_summarytarget/ntsr1_leafsmooth_leafsurface_sumtarget_1201.csv', index_col = [0],  header=[0, 1])
Cux2_conn = pd.read_csv('/Users/samsonkoelle/Downloads/connectivities_ELLeafsmooth_leafsource_summarytarget/cux2_leafsmooth_leafsurface_sumtarget_1201.csv', index_col = [0],  header=[0, 1])
Rbp4_conn = pd.read_csv('/Users/samsonkoelle/Downloads/connectivities_ELLeafsmooth_leafsource_summarytarget/rbp4_leafsmooth_leafsurface_sumtarget_1201.csv', index_col = [0],  header=[0, 1])
Tlx3_conn = pd.read_csv('/Users/samsonkoelle/Downloads/connectivities_ELLeafsmooth_leafsource_summarytarget/tlx3_leafsmooth_leafsurface_sumtarget_1201.csv', index_col = [0],  header=[0, 1])

# %%
Ntsr1_conn.sum(axis = 1)
# Out:
# FRP1
# FRP2/3    0.000000
# FRP5      0.000000
# FRP6a     0.000000
# FRP6b     0.000000
# MOp1      0.000000
#             ...
# PFL       0.000000
# FL        0.000000
# FN        0.000000
# IP        4.726209
# DN        0.000000
# Length: 540, dtype: float64

# %%
Cux2_conn.sum(axis = 1)
# Out:
# FRP1
# FRP2/3    2.332264
# FRP5      0.000000
# FRP6a     0.000000
# FRP6b     0.000000
# MOp1      0.000000
#             ...
# PFL       0.000000
# FL        0.000000
# FN        0.000000
# IP        0.000000
# DN        0.000000
# Length: 540, dtype: float64

# %%
fig, axes = plt.subplots(2,5, figsize = (30,10))
cbar_ax = fig.add_axes([.91, .3, .03, .4])

tp = np.log(wt_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,0], cbar = False)

tp = np.log(wt_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,0], cbar = False)

tp = np.log(Cux2_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,1], cbar = False)

tp = np.log(Cux2_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,1], cbar = False)

tp = np.log(Ntsr1_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,2], cbar = False)

tp = np.log(Ntsr1_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,2], cbar = False)

tp = np.log(Rbp4_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,3], cbar = False)

tp = np.log(Rbp4_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,3], cbar = False)

tp = np.log(Tlx3_conn.loc[source_regions].loc[:,target_regions])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[0,4], cbar = False)

tp = np.log(Tlx3_conn.loc[source_reg].loc[:,targ_reg])
tp.iloc[np.where(tp < -9)] = -9
sns.heatmap(tp, vmin = -9, vmax= 0., ax= axes[1,4], cbar = True,cbar_ax= cbar_ax) #cbar_kws={'label': 'Log projection strength'})
cbar_ax.set_title('Log(Connection Strength)', fontsize = 20)

axes[0,0].set_title('Wild-type (C57BL/6J)', fontsize = 20)
axes[0,1].set_title('Cux2-IRES-Cre_PL', fontsize = 20)
axes[0,2].set_title('Ntsr1-Cre_GN220', fontsize = 20)
axes[0,3].set_title('Rbp4-Cre_KL100', fontsize = 20)
axes[0,4].set_title('Tlx3-Cre_PL56', fontsize = 20)

axes[1,0].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,1].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,2].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,3].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)
axes[1,4].set_yticklabels(axes[1,0].get_yticklabels(), rotation=0)

axes[1,0].set_ylabel('MOp/MOs Sources', fontsize = 20)
axes[0,0].set_ylabel('VISp/VISl Sources', fontsize = 20)

axes[1,1].set_ylabel('')
axes[0,1].set_ylabel('')

axes[1,2].set_ylabel('')
axes[0,2].set_ylabel('')

axes[1,3].set_ylabel('')
axes[0,3].set_ylabel('')

axes[1,4].set_ylabel('')
axes[0,4].set_ylabel('')

axes[1,0].set_xlabel('', fontsize = 20)
axes[0,0].set_xlabel('', fontsize = 20)

axes[1,1].set_xlabel('')
axes[0,1].set_xlabel('')

axes[1,2].set_xlabel('Targets', fontsize = 20)
axes[0,2].set_xlabel('', fontsize = 20)

axes[1,3].set_xlabel('')
axes[0,3].set_xlabel('')

axes[1,4].set_xlabel('')
axes[0,4].set_xlabel('')
#plt.savefig('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/visp_mo_1201')
# Out:
# /Users/samsonkoelle/anaconda3/envs/allen_010719_5/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: divide by zero encountered in log
# Text(0.5, 365.50909090909096, '')

# %%
import pandas as pd
#Rbp4_conn_ll = pd.read_csv('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/paper/connectivities/elle.csv', index_col = [0],  header=[0, 1])
import seaborn as sns

# %%
Rbp4_conn_ll = pd.read_csv('/Users/samsonkoelle/alleninstitute/sambranch/mouse_connectivity_models/analyses/paper/connectivities/ELLeafsmoothleafsurface_summarysource_leaftarget_v3/elleafsurfaceleafsmooth_leafsource_summarytarget_rbp4_v3.csv', index_col = [0],  header=[0, 1])

# %%
sns.heatmap(Rbp4_conn_ll.loc[source_reg].loc[:,targ_reg], vmax = .01)

# %%
Rbp4_conn_ll.loc['MOs5'].sum()
# Out:
# 3.3716597428084034

# %%
Rbp4_conn_ll.loc['MOs5',targ_reg] / 0.002384
# Out:
# first  second
# ipsi   ORBvl      3.835762
#        AId       12.907776
#        AIv        1.742901
#        TEa        2.048754
#        ECT        1.453180
#        BLA        0.577180
#        CEA        0.999974
# Name: MOs5, dtype: float64

# %%
Rbp4_conn_ll.loc['MOs6a',targ_reg]  / 0.000307
# Out:
# first  second
# ipsi   ORBvl     30.614918
#        AId       17.833212
#        AIv        4.998516
#        TEa       17.133081
#        ECT        7.682534
#        BLA        1.319102
#        CEA        1.001442
# Name: MOs6a, dtype: float64

# %%
sns.heatmap(Rbp4_conn_ll.loc[source_reg].loc[:,targ_reg])

# %%
sns.heatmap(Rbp4_conn_ll.loc[source_regions].loc[:,target_regions])

# %%
sns.heatmap(Rbp4_conn_ll.loc[source_reg].loc[:,targ_reg], vmax = .01)

# %%
sns.heatmap(Rbp4_conn.loc[source_reg].loc[:,targ_reg], vmax = .01)
