# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd 
import sys
import pickle
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random
from sklearn.metrics import pairwise_distances
from sklearn.kernel_ridge import KernelRidge
import math

workingdirectory = os.popen('git rev-parse --show-toplevel').read()[:-1]
sys.path.append(workingdirectory)
os.chdir(workingdirectory)

import allensdk.core.json_utilities as ju
from allensdk.core.mouse_connectivity_cache import MouseConnectivityCache

from mcmodels.core import VoxelModelCache
from mcmodels.core.utils import get_structure_id,get_ordered_summary_structures
from mcmodels.core.connectivity_data import get_connectivity_data
from mcmodels.models.crossvalidation import get_nwloocv_predictions_multimodel_merge_dists
from mcmodels.utils import nonzero_unique #, unionize
from mcmodels.models.crossvalidation import get_best_hyperparameters,get_loss_best_hyp,get_loss#get_loocv_predictions,get_loss#get_best_hyperparameters,get_loss_best_hyp,get_loocv_predictions,get_loss
from mcmodels.core.utils import get_leaves_ontologicalorder, get_indices, get_indices2,get_eval_indices,screen_index_matrices,screen_index_matrices2,screen_index_matrices3#get_cre_status,get_minorstructure_dictionary,get_leaves_ontologicalorder
from mcmodels.core.utils import get_indices_2ormore
from mcmodels.regressors import NadarayaWatson
from mcmodels.core.plotting import plot_loss_surface,plot_loss_scatter
# Out:
# /Users/samsonkoelle/anaconda3/envs/allen_010719_5/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.linear_model.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.linear_model. Anything that cannot be imported from sklearn.linear_model is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/samsonkoelle/anaconda3/envs/allen_010719_5/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /Users/samsonkoelle/anaconda3/envs/allen_010719_5/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.decomposition.cdnmf_fast module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.decomposition. Anything that cannot be imported from sklearn.decomposition is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#read data
TOP_DIR = '/Users/samsonkoelle/alleninstitute/mcm_2020/mcm_updated/'
INPUT_JSON = os.path.join(TOP_DIR, 'input_011520.json')
EXPERIMENTS_EXCLUDE_JSON = os.path.join(TOP_DIR, 'experiments_exclude.json')
FILE_DIR = '/Users/samsonkoelle/alleninstitute/mcm_2020/mcm_updated/'
OUTPUT_DIR = os.path.join(FILE_DIR, 'output')

input_data = ju.read(INPUT_JSON)
manifest_file = input_data.get('manifest_file')
manifest_file = os.path.join(TOP_DIR, manifest_file)
experiments_exclude = ju.read(EXPERIMENTS_EXCLUDE_JSON)

#its unclear why the hyperparameters are loaded from the output directory
cache = VoxelModelCache(manifest_file=manifest_file)
major_structures = input_data.get('structures')
major_structure_ids = [get_structure_id(cache, s) for s in major_structures]
data_info = pd.read_excel('/Users/samsonkoelle/alleninstitute/Whole Brain Cre Image Series_curation only.xlsx', 'all datasets curated_070919pull')
data_info.set_index("id", inplace=True)
ontological_order = get_ordered_summary_structures(cache)

mcc = MouseConnectivityCache(manifest_file = '../connectivity/mouse_connectivity_manifest.json')
st = mcc.get_structure_tree()
ai_map = st.get_id_acronym_map()
ia_map = {value: key for key, value in ai_map.items()}

#regionalize voxel model: compare with regional model
#regional parameters
cre = None
eid_set=None
high_res=False
threshold_injection = False

COARSE_STRUCTURE_SET_ID = 2#3#2#167587189#3#2(old)
DEFAULT_STRUCTURE_SET_IDS = tuple([COARSE_STRUCTURE_SET_ID])
tree = cache.get_structure_tree()
default_structures = tree.get_structures_by_set_id(DEFAULT_STRUCTURE_SET_IDS)
default_structure_ids = [st['id'] for st in default_structures if st['id'] != 934]
#cre= True

# %%
connectivity_data = get_connectivity_data(cache, major_structure_ids, experiments_exclude, remove_injection = False,structure_set_id = 167587189)

connectivity_data.get_injection_hemisphere_ids()
connectivity_data.align()
connectivity_data.get_centroids()
connectivity_data.get_data_matrices(default_structure_ids)
connectivity_data.get_crelines(data_info)
with open('data/info/leafs.pickle', 'rb') as handle:
    leafs = pickle.load(handle)
    
connectivity_data.ai_map = ai_map
connectivity_data.get_summarystructures(data_info)
connectivity_data.leafs = leafs
# Out:
# 512
# 703
# 1089
# 1097
# 315
# 313
# 354
# 698
# 771
# 803
# 477
# 549

# %%
#major division segregation is legacy code but convenient for fast cross validation in major division model
#experiments_minor_structures = get_summarystructure_dictionary(connectivity_data, data_info)
#get leaves in ontological order.  Where leafs don't exist, uses summary structure
ontological_order_leaves = get_leaves_ontologicalorder(connectivity_data, ontological_order)
#Key isn't affected by which experiment we choose. This allows default masking to be inherited from the AllenSDK.
sid0 = list(connectivity_data.structure_datas.keys())[0]
eid0 = list(connectivity_data.structure_datas[sid0].experiment_datas.keys())[0]
#Identify keys denoting which voxels correspond to which structure in the ipsi and contra targets.
contra_targetkey = connectivity_data.structure_datas[sid0].projection_mask.get_key(structure_ids=ontological_order_leaves, hemisphere_id=1)
ipsi_targetkey = connectivity_data.structure_datas[sid0].projection_mask.get_key(structure_ids=ontological_order_leaves, hemisphere_id=2)

#contra_targetkey = connectivity_data.structure_datas[sid0].projection_mask.get_key(structure_ids=ontological_order, hemisphere_id=1)
#ipsi_targetkey = connectivity_data.structure_datas[sid0].projection_mask.get_key(structure_ids=ontological_order, hemisphere_id=2)
#get average intensities of projection structures given ipsi and contra keys
#source_key = ontological_order #only relevant here when injection needs to be unionized, but currently a required argument
ipsi_target_regions, ipsi_target_counts = nonzero_unique(ipsi_targetkey, return_counts=True)
contra_target_regions, contra_target_counts = nonzero_unique(contra_targetkey, return_counts=True)

target_order = lambda x: np.array(ontological_order_leaves)[np.isin(ontological_order_leaves, x)]
permutation = lambda x: np.argsort(np.argsort(target_order(x)))
targ_ids = np.concatenate([ipsi_target_regions[permutation(ipsi_target_regions)],
                           contra_target_regions[permutation(contra_target_regions)]])

# %%
import matplotlib.patches as mpatches
import seaborn as sns

reo = [4,7,2,1,10,9,11,3,5,8,6,0]
handles = [mpatches.Patch(color =  cs_col_ipsi_dict[major_structures[i]], label = major_structures[i]) for i in reo]

# %%
ontological_order.shape #2
# Out:
# (291,)

# %%
ontological_order.shape #3
# Out:
# (291,)

# %%
ontological_order.shape #3
# Out:
# (291,)

# %%
len(default_structures)
# Out:
# 316

# %%
len(default_structures)
# Out:
# 12

# %%
len(default_structures)
# Out:
# 51

# %%
COARSE_STRUCTURE_SET_ID = 2#3#2#167587189#3#2(old)
DEFAULT_STRUCTURE_SET_IDS = tuple([COARSE_STRUCTURE_SET_ID])
tree = cache.get_structure_tree()
default_structures = tree.get_structures_by_set_id(DEFAULT_STRUCTURE_SET_IDS)
print(len(default_structures)), default_structures
# Out:
# 12
# (None,
#  [{'acronym': 'Isocortex',
#    'graph_id': 1,
#    'graph_order': 5,
#    'id': 315,
#    'name': 'Isocortex',
#    'structure_id_path': [997, 8, 567, 688, 695, 315],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [112, 255, 113]},
#   {'acronym': 'OLF',
#    'graph_id': 1,
#    'graph_order': 379,
#    'id': 698,
#    'name': 'Olfactory areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 698],
#    'structure_set_ids': [2,
#     3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [154, 210, 189]},
#   {'acronym': 'HPF',
#    'graph_id': 1,
#    'graph_order': 454,
#    'id': 1089,
#    'name': 'Hippocampal formation',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'CTXsp',
#    'graph_id': 1,
#    'graph_order': 555,
#    'id': 703,
#    'name': 'Cortical subplate',
#    'structure_id_path': [997, 8, 567, 688, 703],
#    'structure_set_ids': [2,
#     3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     687527670,
#     114512891],
#    'rgb_triplet': [138, 218, 135]},
#   {'acronym': 'STR',
#    'graph_id': 1,
#    'graph_order': 571,
#    'id': 477,
#    'name': 'Striatum',
#    'structure_id_path': [997, 8, 567, 623, 477],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [152, 214, 249]},
#   {'acronym': 'PAL',
#    'graph_id': 1,
#    'graph_order': 608,
#    'id': 803,
#    'name': 'Pallidum',
#    'structure_id_path': [997, 8, 567, 623, 803],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [133, 153, 204]},
#   {'acronym': 'TH',
#    'graph_id': 1,
#    'graph_order': 641,
#    'id': 549,
#    'name': 'Thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 112, 128]},
#   {'acronym': 'HY',
#    'graph_id': 1,
#    'graph_order': 715,
#    'id': 1097,
#    'name': 'Hypothalamus',
#    'structure_id_path': [997, 8, 343, 1129, 1097],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [230, 68, 56]},
#   {'acronym': 'MB',
#    'graph_id': 1,
#    'graph_order': 806,
#    'id': 313,
#    'name': 'Midbrain',
#    'structure_id_path': [997, 8, 343, 313],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 100, 255]},
#   {'acronym': 'P',
#    'graph_id': 1,
#    'graph_order': 883,
#    'id': 771,
#    'name': 'Pons',
#    'structure_id_path': [997, 8, 343, 1065, 771],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 155, 136]},
#   {'acronym': 'MY',
#    'graph_id': 1,
#    'graph_order': 935,
#    'id': 354,
#    'name': 'Medulla',
#    'structure_id_path': [997, 8, 343, 1065, 354],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 155, 205]},
#   {'acronym': 'CB',
#    'graph_id': 1,
#    'graph_order': 1014,
#    'id': 512,
#    'name': 'Cerebellum',
#    'structure_id_path': [997, 8, 512],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [240, 240, 128]}])

# %%
help(tree.get_structures_by_set_id)
# Out:
# Help on method get_structures_by_set_id in module allensdk.core.structure_tree:
#
# get_structures_by_set_id(structure_set_ids) method of allensdk.core.structure_tree.StructureTree instance
#     Obtain a list of brain structures from by the sets that contain
#     them.
#
#     Parameters
#     ----------
#     structure_set_ids : list of int
#         Get structures belonging to these structure sets.
#
#     Returns
#     -------
#     list of dict :
#         Each item describes a structure.

# %%
COARSE_STRUCTURE_SET_ID = 687527945#2#167587189#3#2(old)
DEFAULT_STRUCTURE_SET_IDS = tuple([COARSE_STRUCTURE_SET_ID])
tree = cache.get_structure_tree()
default_structures = tree.get_structures_by_set_id(DEFAULT_STRUCTURE_SET_IDS)
print(len(default_structures)), default_structures
# Out:
# 293
# (None,
#  [{'acronym': 'FRP',
#    'graph_id': 1,
#    'graph_order': 6,
#    'id': 184,
#    'name': 'Frontal pole, cerebral cortex',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 184],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [38, 143, 69]},
#   {'acronym': 'MOp',
#    'graph_id': 1,
#    'graph_order': 18,
#    'id': 985,
#    'name': 'Primary motor area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 500, 985],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [31, 157, 90]},
#   {'acronym': 'MOs',
#    'graph_id': 1,
#    'graph_order': 24,
#    'id': 993,
#    'name': 'Secondary motor area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 500, 993],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [31, 157, 90]},
#   {'acronym': 'SSp-n',
#    'graph_id': 1,
#    'graph_order': 44,
#    'id': 353,
#    'name': 'Primary somatosensory area, nose',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 353],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-bfd',
#    'graph_id': 1,
#    'graph_order': 51,
#    'id': 329,
#    'name': 'Primary somatosensory area, barrel field',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 329],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-ll',
#    'graph_id': 1,
#    'graph_order': 65,
#    'id': 337,
#    'name': 'Primary somatosensory area, lower limb',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 337],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-m',
#    'graph_id': 1,
#    'graph_order': 72,
#    'id': 345,
#    'name': 'Primary somatosensory area, mouth',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 345],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-ul',
#    'graph_id': 1,
#    'graph_order': 79,
#    'id': 369,
#    'name': 'Primary somatosensory area, upper limb',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 369],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-tr',
#    'graph_id': 1,
#    'graph_order': 86,
#    'id': 361,
#    'name': 'Primary somatosensory area, trunk',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 361],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-un',
#    'graph_id': 1,
#    'graph_order': 93,
#    'id': 182305689,
#    'name': 'Primary somatosensory area, unassigned',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 182305689],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSs',
#    'graph_id': 1,
#    'graph_order': 100,
#    'id': 378,
#    'name': 'Supplemental somatosensory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 378],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'GU',
#    'graph_id': 1,
#    'graph_order': 107,
#    'id': 1057,
#    'name': 'Gustatory areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 1057],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [0, 156, 117]},
#   {'acronym': 'VISC',
#    'graph_id': 1,
#    'graph_order': 114,
#    'id': 677,
#    'name': 'Visceral area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 677],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [17, 173, 131]},
#   {'acronym': 'AUDd',
#    'graph_id': 1,
#    'graph_order': 122,
#    'id': 1011,
#    'name': 'Dorsal auditory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1011],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [1, 147, 153]},
#   {'acronym': 'AUDp',
#    'graph_id': 1,
#    'graph_order': 136,
#    'id': 1002,
#    'name': 'Primary auditory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1002],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [1, 147, 153]},
#   {'acronym': 'AUDpo',
#    'graph_id': 1,
#    'graph_order': 143,
#    'id': 1027,
#    'name': 'Posterior auditory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1027],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [1, 147, 153]},
#   {'acronym': 'AUDv',
#    'graph_id': 1,
#    'graph_order': 150,
#    'id': 1018,
#    'name': 'Ventral auditory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1018],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [1, 147, 153]},
#   {'acronym': 'VISal',
#    'graph_id': 1,
#    'graph_order': 164,
#    'id': 402,
#    'name': 'Anterolateral visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 402],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISam',
#    'graph_id': 1,
#    'graph_order': 171,
#    'id': 394,
#    'name': 'Anteromedial visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 394],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISl',
#    'graph_id': 1,
#    'graph_order': 178,
#    'id': 409,
#    'name': 'Lateral visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 409],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISp',
#    'graph_id': 1,
#    'graph_order': 185,
#    'id': 385,
#    'name': 'Primary visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 385],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISpl',
#    'graph_id': 1,
#    'graph_order': 192,
#    'id': 425,
#    'name': 'Posterolateral visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 425],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISpm',
#    'graph_id': 1,
#    'graph_order': 199,
#    'id': 533,
#    'name': 'posteromedial visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 533],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISli',
#    'graph_id': 1,
#    'graph_order': 206,
#    'id': 312782574,
#    'name': 'Laterointermediate area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782574],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISpor',
#    'graph_id': 1,
#    'graph_order': 213,
#    'id': 312782628,
#    'name': 'Postrhinal area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782628],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'ACAd',
#    'graph_id': 1,
#    'graph_order': 226,
#    'id': 39,
#    'name': 'Anterior cingulate area, dorsal part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 31, 39],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [64, 166, 102]},
#   {'acronym': 'ACAv',
#    'graph_id': 1,
#    'graph_order': 232,
#    'id': 48,
#    'name': 'Anterior cingulate area, ventral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 31, 48],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [64, 166, 102]},
#   {'acronym': 'PL',
#    'graph_id': 1,
#    'graph_order': 238,
#    'id': 972,
#    'name': 'Prelimbic area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 972],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [47, 168, 80]},
#   {'acronym': 'ILA',
#    'graph_id': 1,
#    'graph_order': 245,
#    'id': 44,
#    'name': 'Infralimbic area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 44],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [89, 179, 99]},
#   {'acronym': 'ORBl',
#    'graph_id': 1,
#    'graph_order': 258,
#    'id': 723,
#    'name': 'Orbital area, lateral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 714, 723],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [36, 138, 94]},
#   {'acronym': 'ORBm',
#    'graph_id': 1,
#    'graph_order': 264,
#    'id': 731,
#    'name': 'Orbital area, medial part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 714, 731],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [36, 138, 94]},
#   {'acronym': 'ORBvl',
#    'graph_id': 1,
#    'graph_order': 272,
#    'id': 746,
#    'name': 'Orbital area, ventrolateral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 714, 746],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [36, 138, 94]},
#   {'acronym': 'AId',
#    'graph_id': 1,
#    'graph_order': 279,
#    'id': 104,
#    'name': 'Agranular insular area, dorsal part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 104],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [33, 152, 102]},
#   {'acronym': 'AIp',
#    'graph_id': 1,
#    'graph_order': 285,
#    'id': 111,
#    'name': 'Agranular insular area, posterior part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 111],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [33, 152, 102]},
#   {'acronym': 'AIv',
#    'graph_id': 1,
#    'graph_order': 291,
#    'id': 119,
#    'name': 'Agranular insular area, ventral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 119],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [33, 152, 102]},
#   {'acronym': 'RSPagl',
#    'graph_id': 1,
#    'graph_order': 298,
#    'id': 894,
#    'name': 'Retrosplenial area, lateral agranular part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 254, 894],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [26, 166, 152]},
#   {'acronym': 'RSPd',
#    'graph_id': 1,
#    'graph_order': 325,
#    'id': 879,
#    'name': 'Retrosplenial area, dorsal part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 254, 879],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [26, 166, 152]},
#   {'acronym': 'RSPv',
#    'graph_id': 1,
#    'graph_order': 332,
#    'id': 886,
#    'name': 'Retrosplenial area, ventral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 254, 886],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [26, 166, 152]},
#   {'acronym': 'VISa',
#    'graph_id': 1,
#    'graph_order': 346,
#    'id': 312782546,
#    'name': 'Anterior area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 312782546],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [0, 159, 172]},
#   {'acronym': 'VISrl',
#    'graph_id': 1,
#    'graph_order': 353,
#    'id': 417,
#    'name': 'Rostrolateral visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 417],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [0, 159, 172]},
#   {'acronym': 'TEa',
#    'graph_id': 1,
#    'graph_order': 360,
#    'id': 541,
#    'name': 'Temporal association areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 541],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [21, 176, 179]},
#   {'acronym': 'PERI',
#    'graph_id': 1,
#    'graph_order': 367,
#    'id': 922,
#    'name': 'Perirhinal area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 922],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [14, 150, 132]},
#   {'acronym': 'ECT',
#    'graph_id': 1,
#    'graph_order': 373,
#    'id': 895,
#    'name': 'Ectorhinal area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 895],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [13, 159, 145]},
#   {'acronym': 'MOB',
#    'graph_id': 1,
#    'graph_order': 380,
#    'id': 507,
#    'name': 'Main olfactory bulb',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 507],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [154, 210, 189]},
#   {'acronym': 'AOB',
#    'graph_id': 1,
#    'graph_order': 386,
#    'id': 151,
#    'name': 'Accessory olfactory bulb',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 151],
#    'structure_set_ids': [112905828,
#     688152358,
#     691663206,
#     687527945,
#     10,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [157, 240, 210]},
#   {'acronym': 'AON',
#    'graph_id': 1,
#    'graph_order': 390,
#    'id': 159,
#    'name': 'Anterior olfactory nucleus',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 159],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     10,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [84, 191, 148]},
#   {'acronym': 'TT',
#    'graph_id': 1,
#    'graph_order': 398,
#    'id': 589,
#    'name': 'Taenia tecta',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 589],
#    'structure_set_ids': [112905828,
#     688152358,
#     691663206,
#     687527945,
#     10,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [98, 208, 159]},
#   {'acronym': 'DP',
#    'graph_id': 1,
#    'graph_order': 410,
#    'id': 814,
#    'name': 'Dorsal peduncular area',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 814],
#    'structure_set_ids': [112905828,
#     688152358,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [164, 218, 164]},
#   {'acronym': 'PIR',
#    'graph_id': 1,
#    'graph_order': 416,
#    'id': 961,
#    'name': 'Piriform area',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 961],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     10,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [106, 203, 186]},
#   {'acronym': 'NLOT',
#    'graph_id': 1,
#    'graph_order': 421,
#    'id': 619,
#    'name': 'Nucleus of the lateral olfactory tract',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 619],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     10,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [149, 228, 200]},
#   {'acronym': 'COAa',
#    'graph_id': 1,
#    'graph_order': 427,
#    'id': 639,
#    'name': 'Cortical amygdalar area, anterior part',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 631, 639],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [97, 231, 183]},
#   {'acronym': 'COAp',
#    'graph_id': 1,
#    'graph_order': 431,
#    'id': 647,
#    'name': 'Cortical amygdalar area, posterior part',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 631, 647],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [97, 231, 183]},
#   {'acronym': 'PAA',
#    'graph_id': 1,
#    'graph_order': 444,
#    'id': 788,
#    'name': 'Piriform-amygdalar area',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 788],
#    'structure_set_ids': [112905828,
#     688152358,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [89, 218, 171]},
#   {'acronym': 'TR',
#    'graph_id': 1,
#    'graph_order': 449,
#    'id': 566,
#    'name': 'Postpiriform transition area',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 566],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [168, 236, 211]},
#   {'acronym': 'CA1',
#    'graph_id': 1,
#    'graph_order': 457,
#    'id': 382,
#    'name': 'Field CA1',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 375, 382],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'CA2',
#    'graph_id': 1,
#    'graph_order': 462,
#    'id': 423,
#    'name': 'Field CA2',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 375, 423],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'CA3',
#    'graph_id': 1,
#    'graph_order': 467,
#    'id': 463,
#    'name': 'Field CA3',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 375, 463],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'DG',
#    'graph_id': 1,
#    'graph_order': 473,
#    'id': 726,
#    'name': 'Dentate gyrus',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 726],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     688152359,
#     687527945,
#     10,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'FC',
#    'graph_id': 1,
#    'graph_order': 490,
#    'id': 982,
#    'name': 'Fasciola cinerea',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 982],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'IG',
#    'graph_id': 1,
#    'graph_order': 491,
#    'id': 19,
#    'name': 'Induseum griseum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 19],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'ENTl',
#    'graph_id': 1,
#    'graph_order': 494,
#    'id': 918,
#    'name': 'Entorhinal area, lateral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 909, 918],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [50, 184, 37]},
#   {'acronym': 'ENTm',
#    'graph_id': 1,
#    'graph_order': 507,
#    'id': 926,
#    'name': 'Entorhinal area, medial part, dorsal zone',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 909, 926],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [50, 184, 37]},
#   {'acronym': 'ENTmv',
#    'graph_id': 1,
#    'graph_order': 517,
#    'id': 934,
#    'name': 'Entorhinal area, medial part, ventral zone',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 909, 934],
#    'structure_set_ids': [687527945, 184527634, 12],
#    'rgb_triplet': [50, 184, 37]},
#   {'acronym': 'PAR',
#    'graph_id': 1,
#    'graph_order': 523,
#    'id': 843,
#    'name': 'Parasubiculum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 843],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [114, 213, 105]},
#   {'acronym': 'POST',
#    'graph_id': 1,
#    'graph_order': 527,
#    'id': 1037,
#    'name': 'Postsubiculum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 1037],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [72, 200, 60]},
#   {'acronym': 'PRE',
#    'graph_id': 1,
#    'graph_order': 531,
#    'id': 1084,
#    'name': 'Presubiculum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 1084],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [89, 185, 71]},
#   {'acronym': 'SUB',
#    'graph_id': 1,
#    'graph_order': 535,
#    'id': 502,
#    'name': 'Subiculum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 502],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     10,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [79, 194, 68]},
#   {'acronym': 'CLA',
#    'graph_id': 1,
#    'graph_order': 557,
#    'id': 583,
#    'name': 'Claustrum',
#    'structure_id_path': [997, 8, 567, 688, 703, 583],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     10,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [138, 218, 135]},
#   {'acronym': 'EPd',
#    'graph_id': 1,
#    'graph_order': 559,
#    'id': 952,
#    'name': 'Endopiriform nucleus, dorsal part',
#    'structure_id_path': [997, 8, 567, 688, 703, 942, 952],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [160, 238, 157]},
#   {'acronym': 'EPv',
#    'graph_id': 1,
#    'graph_order': 560,
#    'id': 966,
#    'name': 'Endopiriform nucleus, ventral part',
#    'structure_id_path': [997, 8, 567, 688, 703, 942, 966],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [160, 238, 157]},
#   {'acronym': 'LA',
#    'graph_id': 1,
#    'graph_order': 561,
#    'id': 131,
#    'name': 'Lateral amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 688, 703, 131],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [144, 235, 141]},
#   {'acronym': 'BLA',
#    'graph_id': 1,
#    'graph_order': 562,
#    'id': 295,
#    'name': 'Basolateral amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 688, 703, 295],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [157, 231, 156]},
#   {'acronym': 'BMA',
#    'graph_id': 1,
#    'graph_order': 566,
#    'id': 319,
#    'name': 'Basomedial amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 688, 703, 319],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [132, 234, 129]},
#   {'acronym': 'PA',
#    'graph_id': 1,
#    'graph_order': 569,
#    'id': 780,
#    'name': 'Posterior amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 688, 703, 780],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [151, 236, 147]},
#   {'acronym': 'CP',
#    'graph_id': 1,
#    'graph_order': 573,
#    'id': 672,
#    'name': 'Caudoputamen',
#    'structure_id_path': [997, 8, 567, 623, 477, 485, 672],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152361,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [152, 214, 249]},
#   {'acronym': 'ACB',
#    'graph_id': 1,
#    'graph_order': 575,
#    'id': 56,
#    'name': 'Nucleus accumbens',
#    'structure_id_path': [997, 8, 567, 623, 477, 493, 56],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     10,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 205, 248]},
#   {'acronym': 'FS',
#    'graph_id': 1,
#    'graph_order': 576,
#    'id': 998,
#    'name': 'Fundus of striatum',
#    'structure_id_path': [997, 8, 567, 623, 477, 493, 998],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152361,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [128, 205, 248]},
#   {'acronym': 'OT',
#    'graph_id': 1,
#    'graph_order': 577,
#    'id': 754,
#    'name': 'Olfactory tubercle',
#    'structure_id_path': [997, 8, 567, 623, 477, 493, 754],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     10,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 205, 248]},
#   {'acronym': 'LSc',
#    'graph_id': 1,
#    'graph_order': 587,
#    'id': 250,
#    'name': 'Lateral septal nucleus, caudal (caudodorsal) part',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 242, 250],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     10,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'LSr',
#    'graph_id': 1,
#    'graph_order': 588,
#    'id': 258,
#    'name': 'Lateral septal nucleus, rostral (rostroventral) part',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 242, 258],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'LSv',
#    'graph_id': 1,
#    'graph_order': 589,
#    'id': 266,
#    'name': 'Lateral septal nucleus, ventral part',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 242, 266],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'SF',
#    'graph_id': 1,
#    'graph_order': 590,
#    'id': 310,
#    'name': 'Septofimbrial nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 310],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152361,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'SH',
#    'graph_id': 1,
#    'graph_order': 591,
#    'id': 333,
#    'name': 'Septohippocampal nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 333],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'AAA',
#    'graph_id': 1,
#    'graph_order': 593,
#    'id': 23,
#    'name': 'Anterior amygdalar area',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 23],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152361,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'BA',
#    'graph_id': 1,
#    'graph_order': 594,
#    'id': 292,
#    'name': 'Bed nucleus of the accessory olfactory tract',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 292],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152361,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'CEA',
#    'graph_id': 1,
#    'graph_order': 595,
#    'id': 536,
#    'name': 'Central amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 536],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152361,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'IA',
#    'graph_id': 1,
#    'graph_order': 599,
#    'id': 1105,
#    'name': 'Intercalated amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 1105],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'MEA',
#    'graph_id': 1,
#    'graph_order': 600,
#    'id': 403,
#    'name': 'Medial amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 403],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     10,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'GPe',
#    'graph_id': 1,
#    'graph_order': 610,
#    'id': 1022,
#    'name': 'Globus pallidus, external segment',
#    'structure_id_path': [997, 8, 567, 623, 803, 818, 1022],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [133, 153, 204]},
#   {'acronym': 'GPi',
#    'graph_id': 1,
#    'graph_order': 611,
#    'id': 1031,
#    'name': 'Globus pallidus, internal segment',
#    'structure_id_path': [997, 8, 567, 623, 803, 818, 1031],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [133, 153, 204]},
#   {'acronym': 'SI',
#    'graph_id': 1,
#    'graph_order': 613,
#    'id': 342,
#    'name': 'Substantia innominata',
#    'structure_id_path': [997, 8, 567, 623, 803, 835, 342],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [162, 177, 216]},
#   {'acronym': 'MA',
#    'graph_id': 1,
#    'graph_order': 614,
#    'id': 298,
#    'name': 'Magnocellular nucleus',
#    'structure_id_path': [997, 8, 567, 623, 803, 835, 298],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [162, 177, 216]},
#   {'acronym': 'MS',
#    'graph_id': 1,
#    'graph_order': 617,
#    'id': 564,
#    'name': 'Medial septal nucleus',
#    'structure_id_path': [997, 8, 567, 623, 803, 826, 904, 564],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [150, 167, 211]},
#   {'acronym': 'NDB',
#    'graph_id': 1,
#    'graph_order': 618,
#    'id': 596,
#    'name': 'Diagonal band nucleus',
#    'structure_id_path': [997, 8, 567, 623, 803, 826, 904, 596],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [150, 167, 211]},
#   {'acronym': 'TRS',
#    'graph_id': 1,
#    'graph_order': 619,
#    'id': 581,
#    'name': 'Triangular nucleus of septum',
#    'structure_id_path': [997, 8, 567, 623, 803, 826, 581],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152362,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [150, 167, 211]},
#   {'acronym': 'BST',
#    'graph_id': 1,
#    'graph_order': 621,
#    'id': 351,
#    'name': 'Bed nuclei of the stria terminalis',
#    'structure_id_path': [997, 8, 567, 623, 803, 809, 351],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152362,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [179, 192, 223]},
#   {'acronym': 'BAC',
#    'graph_id': 1,
#    'graph_order': 638,
#    'id': 287,
#    'name': 'Bed nucleus of the anterior commissure',
#    'structure_id_path': [997, 8, 567, 623, 803, 809, 287],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [179, 192, 223]},
#   {'acronym': 'VAL',
#    'graph_id': 1,
#    'graph_order': 644,
#    'id': 629,
#    'name': 'Ventral anterior-lateral complex of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 629],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VM',
#    'graph_id': 1,
#    'graph_order': 645,
#    'id': 685,
#    'name': 'Ventral medial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 685],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VPL',
#    'graph_id': 1,
#    'graph_order': 647,
#    'id': 718,
#    'name': 'Ventral posterolateral nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 709, 718],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VPLpc',
#    'graph_id': 1,
#    'graph_order': 648,
#    'id': 725,
#    'name': 'Ventral posterolateral nucleus of the thalamus, parvicellular part',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 709, 725],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VPM',
#    'graph_id': 1,
#    'graph_order': 649,
#    'id': 733,
#    'name': 'Ventral posteromedial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 709, 733],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VPMpc',
#    'graph_id': 1,
#    'graph_order': 650,
#    'id': 741,
#    'name': 'Ventral posteromedial nucleus of the thalamus, parvicellular part',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 709, 741],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'SPFm',
#    'graph_id': 1,
#    'graph_order': 653,
#    'id': 414,
#    'name': 'Subparafascicular nucleus, magnocellular part',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 406, 414],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'SPFp',
#    'graph_id': 1,
#    'graph_order': 654,
#    'id': 422,
#    'name': 'Subparafascicular nucleus, parvicellular part',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 406, 422],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'SPA',
#    'graph_id': 1,
#    'graph_order': 655,
#    'id': 609,
#    'name': 'Subparafascicular area',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 609],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'PP',
#    'graph_id': 1,
#    'graph_order': 656,
#    'id': 1044,
#    'name': 'Peripeduncular nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 1044],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'MG',
#    'graph_id': 1,
#    'graph_order': 658,
#    'id': 475,
#    'name': 'Medial geniculate complex',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 1008, 475],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'LGd',
#    'graph_id': 1,
#    'graph_order': 662,
#    'id': 170,
#    'name': 'Dorsal part of the lateral geniculate complex',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 1008, 170],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'LP',
#    'graph_id': 1,
#    'graph_order': 668,
#    'id': 218,
#    'name': 'Lateral posterior nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 138, 218],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PO',
#    'graph_id': 1,
#    'graph_order': 669,
#    'id': 1020,
#    'name': 'Posterior complex of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 138, 1020],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'POL',
#    'graph_id': 1,
#    'graph_order': 670,
#    'id': 1029,
#    'name': 'Posterior limiting nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 138, 1029],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'SGN',
#    'graph_id': 1,
#    'graph_order': 671,
#    'id': 325,
#    'name': 'Suprageniculate nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 138, 325],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'AV',
#    'graph_id': 1,
#    'graph_order': 675,
#    'id': 255,
#    'name': 'Anteroventral nucleus of thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 255],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'AM',
#    'graph_id': 1,
#    'graph_order': 676,
#    'id': 127,
#    'name': 'Anteromedial nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 127],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'AD',
#    'graph_id': 1,
#    'graph_order': 679,
#    'id': 64,
#    'name': 'Anterodorsal nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 64],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'IAM',
#    'graph_id': 1,
#    'graph_order': 680,
#    'id': 1120,
#    'name': 'Interanteromedial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 1120],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'IAD',
#    'graph_id': 1,
#    'graph_order': 681,
#    'id': 1113,
#    'name': 'Interanterodorsal nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 1113],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'LD',
#    'graph_id': 1,
#    'graph_order': 682,
#    'id': 155,
#    'name': 'Lateral dorsal nucleus of thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 155],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'IMD',
#    'graph_id': 1,
#    'graph_order': 684,
#    'id': 59,
#    'name': 'Intermediodorsal nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 444, 59],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'MD',
#    'graph_id': 1,
#    'graph_order': 685,
#    'id': 362,
#    'name': 'Mediodorsal nucleus of thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 444, 362],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'SMT',
#    'graph_id': 1,
#    'graph_order': 689,
#    'id': 366,
#    'name': 'Submedial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 444, 366],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PR',
#    'graph_id': 1,
#    'graph_order': 690,
#    'id': 1077,
#    'name': 'Perireunensis nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 444, 1077],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PVT',
#    'graph_id': 1,
#    'graph_order': 692,
#    'id': 149,
#    'name': 'Paraventricular nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 149],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PT',
#    'graph_id': 1,
#    'graph_order': 693,
#    'id': 15,
#    'name': 'Parataenial nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 15],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'RE',
#    'graph_id': 1,
#    'graph_order': 694,
#    'id': 181,
#    'name': 'Nucleus of reuniens',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 181],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'RH',
#    'graph_id': 1,
#    'graph_order': 697,
#    'id': 189,
#    'name': 'Rhomboid nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 189],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'CM',
#    'graph_id': 1,
#    'graph_order': 698,
#    'id': 599,
#    'name': 'Central medial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 599],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PCN',
#    'graph_id': 1,
#    'graph_order': 699,
#    'id': 907,
#    'name': 'Paracentral nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 907],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'CL',
#    'graph_id': 1,
#    'graph_order': 700,
#    'id': 575,
#    'name': 'Central lateral nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 575],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PF',
#    'graph_id': 1,
#    'graph_order': 701,
#    'id': 930,
#    'name': 'Parafascicular nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 930],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'RT',
#    'graph_id': 1,
#    'graph_order': 703,
#    'id': 262,
#    'name': 'Reticular nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 262],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'IGL',
#    'graph_id': 1,
#    'graph_order': 705,
#    'id': 27,
#    'name': 'Intergeniculate leaflet of the lateral geniculate complex',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 1014, 27],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'LGv',
#    'graph_id': 1,
#    'graph_order': 707,
#    'id': 178,
#    'name': 'Ventral part of the lateral geniculate complex',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 1014, 178],
#    'structure_set_ids': [112905828,
# ...
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'AMB',
#    'graph_id': 1,
#    'graph_order': 970,
#    'id': 135,
#    'name': 'Nucleus ambiguus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 135],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     112905813],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'DMX',
#    'graph_id': 1,
#    'graph_order': 973,
#    'id': 839,
#    'name': 'Dorsal motor nucleus of the vagus nerve',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 839],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'GRN',
#    'graph_id': 1,
#    'graph_order': 975,
#    'id': 1048,
#    'name': 'Gigantocellular reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 1048],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'ICB',
#    'graph_id': 1,
#    'graph_order': 976,
#    'id': 372,
#    'name': 'Infracerebellar nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 372],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'IO',
#    'graph_id': 1,
#    'graph_order': 977,
#    'id': 83,
#    'name': 'Inferior olivary complex',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 83],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'IRN',
#    'graph_id': 1,
#    'graph_order': 978,
#    'id': 136,
#    'name': 'Intermediate reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 136],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'ISN',
#    'graph_id': 1,
#    'graph_order': 979,
#    'id': 106,
#    'name': 'Inferior salivatory nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 106],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'LIN',
#    'graph_id': 1,
#    'graph_order': 980,
#    'id': 203,
#    'name': 'Linear nucleus of the medulla',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 203],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'LRN',
#    'graph_id': 1,
#    'graph_order': 981,
#    'id': 235,
#    'name': 'Lateral reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 235],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MARN',
#    'graph_id': 1,
#    'graph_order': 984,
#    'id': 307,
#    'name': 'Magnocellular reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 307],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MDRNd',
#    'graph_id': 1,
#    'graph_order': 986,
#    'id': 1098,
#    'name': 'Medullary reticular nucleus, dorsal part',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 395, 1098],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MDRNv',
#    'graph_id': 1,
#    'graph_order': 987,
#    'id': 1107,
#    'name': 'Medullary reticular nucleus, ventral part',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 395, 1107],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     112905813,
#     167587189,
#     114512892],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PARN',
#    'graph_id': 1,
#    'graph_order': 988,
#    'id': 852,
#    'name': 'Parvicellular reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 852],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PAS',
#    'graph_id': 1,
#    'graph_order': 989,
#    'id': 859,
#    'name': 'Parasolitary nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 859],
#    'structure_set_ids': [691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PGRNd',
#    'graph_id': 1,
#    'graph_order': 991,
#    'id': 970,
#    'name': 'Paragigantocellular reticular nucleus, dorsal part',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 938, 970],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PGRNl',
#    'graph_id': 1,
#    'graph_order': 992,
#    'id': 978,
#    'name': 'Paragigantocellular reticular nucleus, lateral part',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 938, 978],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'NR',
#    'graph_id': 1,
#    'graph_order': 995,
#    'id': 177,
#    'name': 'Nucleus of Roller',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 154, 177],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PRP',
#    'graph_id': 1,
#    'graph_order': 996,
#    'id': 169,
#    'name': 'Nucleus prepositus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 154, 169],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PPY',
#    'graph_id': 1,
#    'graph_order': 998,
#    'id': 1069,
#    'name': 'Parapyramidal nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 1069],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'LAV',
#    'graph_id': 1,
#    'graph_order': 1002,
#    'id': 209,
#    'name': 'Lateral vestibular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 209],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MV',
#    'graph_id': 1,
#    'graph_order': 1003,
#    'id': 202,
#    'name': 'Medial vestibular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 202],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'SPIV',
#    'graph_id': 1,
#    'graph_order': 1004,
#    'id': 225,
#    'name': 'Spinal vestibular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 225],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'SUV',
#    'graph_id': 1,
#    'graph_order': 1005,
#    'id': 217,
#    'name': 'Superior vestibular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 217],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'x',
#    'graph_id': 1,
#    'graph_order': 1006,
#    'id': 765,
#    'name': 'Nucleus x',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 765],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'XII',
#    'graph_id': 1,
#    'graph_order': 1007,
#    'id': 773,
#    'name': 'Hypoglossal nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 773],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'y',
#    'graph_id': 1,
#    'graph_order': 1008,
#    'id': 781,
#    'name': 'Nucleus y',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 781],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'RM',
#    'graph_id': 1,
#    'graph_order': 1011,
#    'id': 206,
#    'name': 'Nucleus raphe magnus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 379, 206],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 198, 226]},
#   {'acronym': 'RPA',
#    'graph_id': 1,
#    'graph_order': 1012,
#    'id': 230,
#    'name': 'Nucleus raphe pallidus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 379, 230],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 198, 226]},
#   {'acronym': 'RO',
#    'graph_id': 1,
#    'graph_order': 1013,
#    'id': 222,
#    'name': 'Nucleus raphe obscurus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 379, 222],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 198, 226]},
#   {'acronym': 'LING',
#    'graph_id': 1,
#    'graph_order': 1020,
#    'id': 912,
#    'name': 'Lingula (I)',
#    'structure_id_path': [997, 8, 512, 528, 645, 912],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'CENT',
#    'graph_id': 1,
#    'graph_order': 1024,
#    'id': 920,
#    'name': 'Central lobule',
#    'structure_id_path': [997, 8, 512, 528, 645, 920],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'CUL',
#    'graph_id': 1,
#    'graph_order': 1033,
#    'id': 928,
#    'name': 'Culmen',
#    'structure_id_path': [997, 8, 512, 528, 645, 928],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'DEC',
#    'graph_id': 1,
#    'graph_order': 1046,
#    'id': 936,
#    'name': 'Declive (VI)',
#    'structure_id_path': [997, 8, 512, 528, 645, 936],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'FOTU',
#    'graph_id': 1,
#    'graph_order': 1050,
#    'id': 944,
#    'name': 'Folium-tuber vermis (VII)',
#    'structure_id_path': [997, 8, 512, 528, 645, 944],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'PYR',
#    'graph_id': 1,
#    'graph_order': 1054,
#    'id': 951,
#    'name': 'Pyramus (VIII)',
#    'structure_id_path': [997, 8, 512, 528, 645, 951],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'UVU',
#    'graph_id': 1,
#    'graph_order': 1058,
#    'id': 957,
#    'name': 'Uvula (IX)',
#    'structure_id_path': [997, 8, 512, 528, 645, 957],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'NOD',
#    'graph_id': 1,
#    'graph_order': 1062,
#    'id': 968,
#    'name': 'Nodulus (X)',
#    'structure_id_path': [997, 8, 512, 528, 645, 968],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'SIM',
#    'graph_id': 1,
#    'graph_order': 1067,
#    'id': 1007,
#    'name': 'Simple lobule',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1007],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'AN',
#    'graph_id': 1,
#    'graph_order': 1071,
#    'id': 1017,
#    'name': 'Ansiform lobule',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1017],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'PRM',
#    'graph_id': 1,
#    'graph_order': 1080,
#    'id': 1025,
#    'name': 'Paramedian lobule',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1025],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'COPY',
#    'graph_id': 1,
#    'graph_order': 1084,
#    'id': 1033,
#    'name': 'Copula pyramidis',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1033],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'PFL',
#    'graph_id': 1,
#    'graph_order': 1088,
#    'id': 1041,
#    'name': 'Paraflocculus',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1041],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'FL',
#    'graph_id': 1,
#    'graph_order': 1092,
#    'id': 1049,
#    'name': 'Flocculus',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1049],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'FN',
#    'graph_id': 1,
#    'graph_order': 1097,
#    'id': 989,
#    'name': 'Fastigial nucleus',
#    'structure_id_path': [997, 8, 512, 519, 989],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 253, 188]},
#   {'acronym': 'IP',
#    'graph_id': 1,
#    'graph_order': 1098,
#    'id': 91,
#    'name': 'Interposed nucleus',
#    'structure_id_path': [997, 8, 512, 519, 91],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 253, 188]},
#   {'acronym': 'DN',
#    'graph_id': 1,
#    'graph_order': 1099,
#    'id': 846,
#    'name': 'Dentate nucleus',
#    'structure_id_path': [997, 8, 512, 519, 846],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 253, 188]},
#   {'acronym': 'fiber tracts',
#    'graph_id': 1,
#    'graph_order': 1101,
#    'id': 1009,
#    'name': 'fiber tracts',
#    'structure_id_path': [997, 1009],
#    'structure_set_ids': [687527945, 184527634, 167587189, 691663206],
#    'rgb_triplet': [204, 204, 204]}])

# %%
default_structures_old = default_structures.copy()

# %%
COARSE_STRUCTURE_SET_ID = 687527670#2#167587189#3#2(old)
DEFAULT_STRUCTURE_SET_IDS = tuple([COARSE_STRUCTURE_SET_ID])
tree = cache.get_structure_tree()
default_structures = tree.get_structures_by_set_id(DEFAULT_STRUCTURE_SET_IDS)
print(len(default_structures)), default_structures
# Out:
# 12
# (None,
#  [{'acronym': 'Isocortex',
#    'graph_id': 1,
#    'graph_order': 5,
#    'id': 315,
#    'name': 'Isocortex',
#    'structure_id_path': [997, 8, 567, 688, 695, 315],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [112, 255, 113]},
#   {'acronym': 'OLF',
#    'graph_id': 1,
#    'graph_order': 379,
#    'id': 698,
#    'name': 'Olfactory areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 698],
#    'structure_set_ids': [2,
#     3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [154, 210, 189]},
#   {'acronym': 'HPF',
#    'graph_id': 1,
#    'graph_order': 454,
#    'id': 1089,
#    'name': 'Hippocampal formation',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'CTXsp',
#    'graph_id': 1,
#    'graph_order': 555,
#    'id': 703,
#    'name': 'Cortical subplate',
#    'structure_id_path': [997, 8, 567, 688, 703],
#    'structure_set_ids': [2,
#     3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     687527670,
#     114512891],
#    'rgb_triplet': [138, 218, 135]},
#   {'acronym': 'STR',
#    'graph_id': 1,
#    'graph_order': 571,
#    'id': 477,
#    'name': 'Striatum',
#    'structure_id_path': [997, 8, 567, 623, 477],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [152, 214, 249]},
#   {'acronym': 'PAL',
#    'graph_id': 1,
#    'graph_order': 608,
#    'id': 803,
#    'name': 'Pallidum',
#    'structure_id_path': [997, 8, 567, 623, 803],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [133, 153, 204]},
#   {'acronym': 'TH',
#    'graph_id': 1,
#    'graph_order': 641,
#    'id': 549,
#    'name': 'Thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 112, 128]},
#   {'acronym': 'HY',
#    'graph_id': 1,
#    'graph_order': 715,
#    'id': 1097,
#    'name': 'Hypothalamus',
#    'structure_id_path': [997, 8, 343, 1129, 1097],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [230, 68, 56]},
#   {'acronym': 'MB',
#    'graph_id': 1,
#    'graph_order': 806,
#    'id': 313,
#    'name': 'Midbrain',
#    'structure_id_path': [997, 8, 343, 313],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 100, 255]},
#   {'acronym': 'P',
#    'graph_id': 1,
#    'graph_order': 883,
#    'id': 771,
#    'name': 'Pons',
#    'structure_id_path': [997, 8, 343, 1065, 771],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 155, 136]},
#   {'acronym': 'MY',
#    'graph_id': 1,
#    'graph_order': 935,
#    'id': 354,
#    'name': 'Medulla',
#    'structure_id_path': [997, 8, 343, 1065, 354],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 155, 205]},
#   {'acronym': 'CB',
#    'graph_id': 1,
#    'graph_order': 1014,
#    'id': 512,
#    'name': 'Cerebellum',
#    'structure_id_path': [997, 8, 512],
#    'structure_set_ids': [2,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [240, 240, 128]}])

# %%
COARSE_STRUCTURE_SET_ID = 167587189#2#167587189#3#2(old)
DEFAULT_STRUCTURE_SET_IDS = tuple([COARSE_STRUCTURE_SET_ID])
tree = cache.get_structure_tree()
default_structures = tree.get_structures_by_set_id(DEFAULT_STRUCTURE_SET_IDS)
print(len(default_structures)), default_structures
# Out:
# 316
# (None,
#  [{'acronym': 'FRP',
#    'graph_id': 1,
#    'graph_order': 6,
#    'id': 184,
#    'name': 'Frontal pole, cerebral cortex',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 184],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [38, 143, 69]},
#   {'acronym': 'MOp',
#    'graph_id': 1,
#    'graph_order': 18,
#    'id': 985,
#    'name': 'Primary motor area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 500, 985],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [31, 157, 90]},
#   {'acronym': 'MOs',
#    'graph_id': 1,
#    'graph_order': 24,
#    'id': 993,
#    'name': 'Secondary motor area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 500, 993],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [31, 157, 90]},
#   {'acronym': 'SSp-n',
#    'graph_id': 1,
#    'graph_order': 44,
#    'id': 353,
#    'name': 'Primary somatosensory area, nose',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 353],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-bfd',
#    'graph_id': 1,
#    'graph_order': 51,
#    'id': 329,
#    'name': 'Primary somatosensory area, barrel field',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 329],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-ll',
#    'graph_id': 1,
#    'graph_order': 65,
#    'id': 337,
#    'name': 'Primary somatosensory area, lower limb',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 337],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-m',
#    'graph_id': 1,
#    'graph_order': 72,
#    'id': 345,
#    'name': 'Primary somatosensory area, mouth',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 345],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-ul',
#    'graph_id': 1,
#    'graph_order': 79,
#    'id': 369,
#    'name': 'Primary somatosensory area, upper limb',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 369],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-tr',
#    'graph_id': 1,
#    'graph_order': 86,
#    'id': 361,
#    'name': 'Primary somatosensory area, trunk',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 361],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSp-un',
#    'graph_id': 1,
#    'graph_order': 93,
#    'id': 182305689,
#    'name': 'Primary somatosensory area, unassigned',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 322, 182305689],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'SSs',
#    'graph_id': 1,
#    'graph_order': 100,
#    'id': 378,
#    'name': 'Supplemental somatosensory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453, 378],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'GU',
#    'graph_id': 1,
#    'graph_order': 107,
#    'id': 1057,
#    'name': 'Gustatory areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 1057],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [0, 156, 117]},
#   {'acronym': 'VISC',
#    'graph_id': 1,
#    'graph_order': 114,
#    'id': 677,
#    'name': 'Visceral area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 677],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [17, 173, 131]},
#   {'acronym': 'AUDd',
#    'graph_id': 1,
#    'graph_order': 122,
#    'id': 1011,
#    'name': 'Dorsal auditory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1011],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [1, 147, 153]},
#   {'acronym': 'AUDp',
#    'graph_id': 1,
#    'graph_order': 136,
#    'id': 1002,
#    'name': 'Primary auditory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1002],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [1, 147, 153]},
#   {'acronym': 'AUDpo',
#    'graph_id': 1,
#    'graph_order': 143,
#    'id': 1027,
#    'name': 'Posterior auditory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1027],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [1, 147, 153]},
#   {'acronym': 'AUDv',
#    'graph_id': 1,
#    'graph_order': 150,
#    'id': 1018,
#    'name': 'Ventral auditory area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 247, 1018],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [1, 147, 153]},
#   {'acronym': 'VISal',
#    'graph_id': 1,
#    'graph_order': 164,
#    'id': 402,
#    'name': 'Anterolateral visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 402],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISam',
#    'graph_id': 1,
#    'graph_order': 171,
#    'id': 394,
#    'name': 'Anteromedial visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 394],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISl',
#    'graph_id': 1,
#    'graph_order': 178,
#    'id': 409,
#    'name': 'Lateral visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 409],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISp',
#    'graph_id': 1,
#    'graph_order': 185,
#    'id': 385,
#    'name': 'Primary visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 385],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISpl',
#    'graph_id': 1,
#    'graph_order': 192,
#    'id': 425,
#    'name': 'Posterolateral visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 425],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISpm',
#    'graph_id': 1,
#    'graph_order': 199,
#    'id': 533,
#    'name': 'posteromedial visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 533],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     514166994,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISli',
#    'graph_id': 1,
#    'graph_order': 206,
#    'id': 312782574,
#    'name': 'Laterointermediate area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782574],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'VISpor',
#    'graph_id': 1,
#    'graph_order': 213,
#    'id': 312782628,
#    'name': 'Postrhinal area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669, 312782628],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'ACAd',
#    'graph_id': 1,
#    'graph_order': 226,
#    'id': 39,
#    'name': 'Anterior cingulate area, dorsal part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 31, 39],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [64, 166, 102]},
#   {'acronym': 'ACAv',
#    'graph_id': 1,
#    'graph_order': 232,
#    'id': 48,
#    'name': 'Anterior cingulate area, ventral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 31, 48],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [64, 166, 102]},
#   {'acronym': 'PL',
#    'graph_id': 1,
#    'graph_order': 238,
#    'id': 972,
#    'name': 'Prelimbic area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 972],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [47, 168, 80]},
#   {'acronym': 'ILA',
#    'graph_id': 1,
#    'graph_order': 245,
#    'id': 44,
#    'name': 'Infralimbic area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 44],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [89, 179, 99]},
#   {'acronym': 'ORBl',
#    'graph_id': 1,
#    'graph_order': 258,
#    'id': 723,
#    'name': 'Orbital area, lateral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 714, 723],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [36, 138, 94]},
#   {'acronym': 'ORBm',
#    'graph_id': 1,
#    'graph_order': 264,
#    'id': 731,
#    'name': 'Orbital area, medial part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 714, 731],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [36, 138, 94]},
#   {'acronym': 'ORBvl',
#    'graph_id': 1,
#    'graph_order': 272,
#    'id': 746,
#    'name': 'Orbital area, ventrolateral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 714, 746],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [36, 138, 94]},
#   {'acronym': 'AId',
#    'graph_id': 1,
#    'graph_order': 279,
#    'id': 104,
#    'name': 'Agranular insular area, dorsal part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 104],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [33, 152, 102]},
#   {'acronym': 'AIp',
#    'graph_id': 1,
#    'graph_order': 285,
#    'id': 111,
#    'name': 'Agranular insular area, posterior part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 111],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [33, 152, 102]},
#   {'acronym': 'AIv',
#    'graph_id': 1,
#    'graph_order': 291,
#    'id': 119,
#    'name': 'Agranular insular area, ventral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 95, 119],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [33, 152, 102]},
#   {'acronym': 'RSPagl',
#    'graph_id': 1,
#    'graph_order': 298,
#    'id': 894,
#    'name': 'Retrosplenial area, lateral agranular part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 254, 894],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [26, 166, 152]},
#   {'acronym': 'RSPd',
#    'graph_id': 1,
#    'graph_order': 325,
#    'id': 879,
#    'name': 'Retrosplenial area, dorsal part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 254, 879],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [26, 166, 152]},
#   {'acronym': 'RSPv',
#    'graph_id': 1,
#    'graph_order': 332,
#    'id': 886,
#    'name': 'Retrosplenial area, ventral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 254, 886],
#    'structure_set_ids': [112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [26, 166, 152]},
#   {'acronym': 'VISa',
#    'graph_id': 1,
#    'graph_order': 346,
#    'id': 312782546,
#    'name': 'Anterior area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 312782546],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [0, 159, 172]},
#   {'acronym': 'VISrl',
#    'graph_id': 1,
#    'graph_order': 353,
#    'id': 417,
#    'name': 'Rostrolateral visual area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 22, 417],
#    'structure_set_ids': [396673091,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     184527634,
#     514166994,
#     167587189,
#     114512891],
#    'rgb_triplet': [0, 159, 172]},
#   {'acronym': 'TEa',
#    'graph_id': 1,
#    'graph_order': 360,
#    'id': 541,
#    'name': 'Temporal association areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 541],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [21, 176, 179]},
#   {'acronym': 'PERI',
#    'graph_id': 1,
#    'graph_order': 367,
#    'id': 922,
#    'name': 'Perirhinal area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 922],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [14, 150, 132]},
#   {'acronym': 'ECT',
#    'graph_id': 1,
#    'graph_order': 373,
#    'id': 895,
#    'name': 'Ectorhinal area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 895],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [13, 159, 145]},
#   {'acronym': 'MOB',
#    'graph_id': 1,
#    'graph_order': 380,
#    'id': 507,
#    'name': 'Main olfactory bulb',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 507],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [154, 210, 189]},
#   {'acronym': 'AOB',
#    'graph_id': 1,
#    'graph_order': 386,
#    'id': 151,
#    'name': 'Accessory olfactory bulb',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 151],
#    'structure_set_ids': [112905828,
#     688152358,
#     691663206,
#     687527945,
#     10,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [157, 240, 210]},
#   {'acronym': 'AON',
#    'graph_id': 1,
#    'graph_order': 390,
#    'id': 159,
#    'name': 'Anterior olfactory nucleus',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 159],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     10,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [84, 191, 148]},
#   {'acronym': 'TT',
#    'graph_id': 1,
#    'graph_order': 398,
#    'id': 589,
#    'name': 'Taenia tecta',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 589],
#    'structure_set_ids': [112905828,
#     688152358,
#     691663206,
#     687527945,
#     10,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [98, 208, 159]},
#   {'acronym': 'DP',
#    'graph_id': 1,
#    'graph_order': 410,
#    'id': 814,
#    'name': 'Dorsal peduncular area',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 814],
#    'structure_set_ids': [112905828,
#     688152358,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [164, 218, 164]},
#   {'acronym': 'PIR',
#    'graph_id': 1,
#    'graph_order': 416,
#    'id': 961,
#    'name': 'Piriform area',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 961],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     10,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [106, 203, 186]},
#   {'acronym': 'NLOT',
#    'graph_id': 1,
#    'graph_order': 421,
#    'id': 619,
#    'name': 'Nucleus of the lateral olfactory tract',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 619],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     10,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [149, 228, 200]},
#   {'acronym': 'COAa',
#    'graph_id': 1,
#    'graph_order': 427,
#    'id': 639,
#    'name': 'Cortical amygdalar area, anterior part',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 631, 639],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [97, 231, 183]},
#   {'acronym': 'COAp',
#    'graph_id': 1,
#    'graph_order': 431,
#    'id': 647,
#    'name': 'Cortical amygdalar area, posterior part',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 631, 647],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [97, 231, 183]},
#   {'acronym': 'PAA',
#    'graph_id': 1,
#    'graph_order': 444,
#    'id': 788,
#    'name': 'Piriform-amygdalar area',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 788],
#    'structure_set_ids': [112905828,
#     688152358,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [89, 218, 171]},
#   {'acronym': 'TR',
#    'graph_id': 1,
#    'graph_order': 449,
#    'id': 566,
#    'name': 'Postpiriform transition area',
#    'structure_id_path': [997, 8, 567, 688, 695, 698, 566],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152358,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [168, 236, 211]},
#   {'acronym': 'CA1',
#    'graph_id': 1,
#    'graph_order': 457,
#    'id': 382,
#    'name': 'Field CA1',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 375, 382],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'CA2',
#    'graph_id': 1,
#    'graph_order': 462,
#    'id': 423,
#    'name': 'Field CA2',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 375, 423],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'CA3',
#    'graph_id': 1,
#    'graph_order': 467,
#    'id': 463,
#    'name': 'Field CA3',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 375, 463],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'DG',
#    'graph_id': 1,
#    'graph_order': 473,
#    'id': 726,
#    'name': 'Dentate gyrus',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 726],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     688152359,
#     687527945,
#     10,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'FC',
#    'graph_id': 1,
#    'graph_order': 490,
#    'id': 982,
#    'name': 'Fasciola cinerea',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 982],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'IG',
#    'graph_id': 1,
#    'graph_order': 491,
#    'id': 19,
#    'name': 'Induseum griseum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 19],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'ENTl',
#    'graph_id': 1,
#    'graph_order': 494,
#    'id': 918,
#    'name': 'Entorhinal area, lateral part',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 909, 918],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [50, 184, 37]},
#   {'acronym': 'ENTm',
#    'graph_id': 1,
#    'graph_order': 507,
#    'id': 926,
#    'name': 'Entorhinal area, medial part, dorsal zone',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 909, 926],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [50, 184, 37]},
#   {'acronym': 'PAR',
#    'graph_id': 1,
#    'graph_order': 523,
#    'id': 843,
#    'name': 'Parasubiculum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 843],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [114, 213, 105]},
#   {'acronym': 'POST',
#    'graph_id': 1,
#    'graph_order': 527,
#    'id': 1037,
#    'name': 'Postsubiculum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 1037],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [72, 200, 60]},
#   {'acronym': 'PRE',
#    'graph_id': 1,
#    'graph_order': 531,
#    'id': 1084,
#    'name': 'Presubiculum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 1084],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [89, 185, 71]},
#   {'acronym': 'SUB',
#    'graph_id': 1,
#    'graph_order': 535,
#    'id': 502,
#    'name': 'Subiculum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 502],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     687527945,
#     10,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [79, 194, 68]},
#   {'acronym': 'ProS',
#    'graph_id': 1,
#    'graph_order': 544,
#    'id': 484682470,
#    'name': 'Prosubiculum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 484682470],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [88, 186, 72]},
#   {'acronym': 'HATA',
#    'graph_id': 1,
#    'graph_order': 553,
#    'id': 589508447,
#    'name': 'Hippocampo-amygdalar transition area',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 589508447],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     184527634,
#     167587189],
#    'rgb_triplet': [51, 185, 50]},
#   {'acronym': 'APr',
#    'graph_id': 1,
#    'graph_order': 554,
#    'id': 484682508,
#    'name': 'Area prostriata',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822, 484682508],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152359,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [51, 185, 50]},
#   {'acronym': 'CLA',
#    'graph_id': 1,
#    'graph_order': 557,
#    'id': 583,
#    'name': 'Claustrum',
#    'structure_id_path': [997, 8, 567, 688, 703, 583],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     10,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [138, 218, 135]},
#   {'acronym': 'EPd',
#    'graph_id': 1,
#    'graph_order': 559,
#    'id': 952,
#    'name': 'Endopiriform nucleus, dorsal part',
#    'structure_id_path': [997, 8, 567, 688, 703, 942, 952],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [160, 238, 157]},
#   {'acronym': 'EPv',
#    'graph_id': 1,
#    'graph_order': 560,
#    'id': 966,
#    'name': 'Endopiriform nucleus, ventral part',
#    'structure_id_path': [997, 8, 567, 688, 703, 942, 966],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [160, 238, 157]},
#   {'acronym': 'LA',
#    'graph_id': 1,
#    'graph_order': 561,
#    'id': 131,
#    'name': 'Lateral amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 688, 703, 131],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [144, 235, 141]},
#   {'acronym': 'BLA',
#    'graph_id': 1,
#    'graph_order': 562,
#    'id': 295,
#    'name': 'Basolateral amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 688, 703, 295],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [157, 231, 156]},
#   {'acronym': 'BMA',
#    'graph_id': 1,
#    'graph_order': 566,
#    'id': 319,
#    'name': 'Basomedial amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 688, 703, 319],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [132, 234, 129]},
#   {'acronym': 'PA',
#    'graph_id': 1,
#    'graph_order': 569,
#    'id': 780,
#    'name': 'Posterior amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 688, 703, 780],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152360,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [151, 236, 147]},
#   {'acronym': 'CP',
#    'graph_id': 1,
#    'graph_order': 573,
#    'id': 672,
#    'name': 'Caudoputamen',
#    'structure_id_path': [997, 8, 567, 623, 477, 485, 672],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152361,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [152, 214, 249]},
#   {'acronym': 'ACB',
#    'graph_id': 1,
#    'graph_order': 575,
#    'id': 56,
#    'name': 'Nucleus accumbens',
#    'structure_id_path': [997, 8, 567, 623, 477, 493, 56],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     10,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 205, 248]},
#   {'acronym': 'FS',
#    'graph_id': 1,
#    'graph_order': 576,
#    'id': 998,
#    'name': 'Fundus of striatum',
#    'structure_id_path': [997, 8, 567, 623, 477, 493, 998],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152361,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [128, 205, 248]},
#   {'acronym': 'OT',
#    'graph_id': 1,
#    'graph_order': 577,
#    'id': 754,
#    'name': 'Olfactory tubercle',
#    'structure_id_path': [997, 8, 567, 623, 477, 493, 754],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     10,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 205, 248]},
#   {'acronym': 'LSc',
#    'graph_id': 1,
#    'graph_order': 587,
#    'id': 250,
#    'name': 'Lateral septal nucleus, caudal (caudodorsal) part',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 242, 250],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     10,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'LSr',
#    'graph_id': 1,
#    'graph_order': 588,
#    'id': 258,
#    'name': 'Lateral septal nucleus, rostral (rostroventral) part',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 242, 258],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     687527945,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'LSv',
#    'graph_id': 1,
#    'graph_order': 589,
#    'id': 266,
#    'name': 'Lateral septal nucleus, ventral part',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 242, 266],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'SF',
#    'graph_id': 1,
#    'graph_order': 590,
#    'id': 310,
#    'name': 'Septofimbrial nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 310],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152361,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'SH',
#    'graph_id': 1,
#    'graph_order': 591,
#    'id': 333,
#    'name': 'Septohippocampal nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 275, 333],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'AAA',
#    'graph_id': 1,
#    'graph_order': 593,
#    'id': 23,
#    'name': 'Anterior amygdalar area',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 23],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152361,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'BA',
#    'graph_id': 1,
#    'graph_order': 594,
#    'id': 292,
#    'name': 'Bed nucleus of the accessory olfactory tract',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 292],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152361,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'CEA',
#    'graph_id': 1,
#    'graph_order': 595,
#    'id': 536,
#    'name': 'Central amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 536],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152361,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'IA',
#    'graph_id': 1,
#    'graph_order': 599,
#    'id': 1105,
#    'name': 'Intercalated amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 1105],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'MEA',
#    'graph_id': 1,
#    'graph_order': 600,
#    'id': 403,
#    'name': 'Medial amygdalar nucleus',
#    'structure_id_path': [997, 8, 567, 623, 477, 278, 403],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152361,
#     10,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'GPe',
#    'graph_id': 1,
#    'graph_order': 610,
#    'id': 1022,
#    'name': 'Globus pallidus, external segment',
#    'structure_id_path': [997, 8, 567, 623, 803, 818, 1022],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [133, 153, 204]},
#   {'acronym': 'GPi',
#    'graph_id': 1,
#    'graph_order': 611,
#    'id': 1031,
#    'name': 'Globus pallidus, internal segment',
#    'structure_id_path': [997, 8, 567, 623, 803, 818, 1031],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [133, 153, 204]},
#   {'acronym': 'SI',
#    'graph_id': 1,
#    'graph_order': 613,
#    'id': 342,
#    'name': 'Substantia innominata',
#    'structure_id_path': [997, 8, 567, 623, 803, 835, 342],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [162, 177, 216]},
#   {'acronym': 'MA',
#    'graph_id': 1,
#    'graph_order': 614,
#    'id': 298,
#    'name': 'Magnocellular nucleus',
#    'structure_id_path': [997, 8, 567, 623, 803, 835, 298],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [162, 177, 216]},
#   {'acronym': 'MS',
#    'graph_id': 1,
#    'graph_order': 617,
#    'id': 564,
#    'name': 'Medial septal nucleus',
#    'structure_id_path': [997, 8, 567, 623, 803, 826, 904, 564],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [150, 167, 211]},
#   {'acronym': 'NDB',
#    'graph_id': 1,
#    'graph_order': 618,
#    'id': 596,
#    'name': 'Diagonal band nucleus',
#    'structure_id_path': [997, 8, 567, 623, 803, 826, 904, 596],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [150, 167, 211]},
#   {'acronym': 'TRS',
#    'graph_id': 1,
#    'graph_order': 619,
#    'id': 581,
#    'name': 'Triangular nucleus of septum',
#    'structure_id_path': [997, 8, 567, 623, 803, 826, 581],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152362,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [150, 167, 211]},
#   {'acronym': 'BST',
#    'graph_id': 1,
#    'graph_order': 621,
#    'id': 351,
#    'name': 'Bed nuclei of the stria terminalis',
#    'structure_id_path': [997, 8, 567, 623, 803, 809, 351],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152362,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [179, 192, 223]},
#   {'acronym': 'BAC',
#    'graph_id': 1,
#    'graph_order': 638,
#    'id': 287,
#    'name': 'Bed nucleus of the anterior commissure',
#    'structure_id_path': [997, 8, 567, 623, 803, 809, 287],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152362,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [179, 192, 223]},
#   {'acronym': 'VAL',
#    'graph_id': 1,
#    'graph_order': 644,
#    'id': 629,
#    'name': 'Ventral anterior-lateral complex of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 629],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VM',
#    'graph_id': 1,
#    'graph_order': 645,
#    'id': 685,
#    'name': 'Ventral medial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 685],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VPL',
#    'graph_id': 1,
#    'graph_order': 647,
#    'id': 718,
#    'name': 'Ventral posterolateral nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 709, 718],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VPLpc',
#    'graph_id': 1,
#    'graph_order': 648,
#    'id': 725,
#    'name': 'Ventral posterolateral nucleus of the thalamus, parvicellular part',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 709, 725],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VPM',
#    'graph_id': 1,
#    'graph_order': 649,
#    'id': 733,
#    'name': 'Ventral posteromedial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 709, 733],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'VPMpc',
#    'graph_id': 1,
#    'graph_order': 650,
#    'id': 741,
#    'name': 'Ventral posteromedial nucleus of the thalamus, parvicellular part',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 709, 741],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'PoT',
#    'graph_id': 1,
#    'graph_order': 651,
#    'id': 563807435,
#    'name': 'Posterior triangular thalamic nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 637, 563807435],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152363,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'SPFm',
#    'graph_id': 1,
#    'graph_order': 653,
#    'id': 414,
#    'name': 'Subparafascicular nucleus, magnocellular part',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 406, 414],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'SPFp',
#    'graph_id': 1,
#    'graph_order': 654,
#    'id': 422,
#    'name': 'Subparafascicular nucleus, parvicellular part',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 406, 422],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'SPA',
#    'graph_id': 1,
#    'graph_order': 655,
#    'id': 609,
#    'name': 'Subparafascicular area',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 609],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'PP',
#    'graph_id': 1,
#    'graph_order': 656,
#    'id': 1044,
#    'name': 'Peripeduncular nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 1044],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'MG',
#    'graph_id': 1,
#    'graph_order': 658,
#    'id': 475,
#    'name': 'Medial geniculate complex',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 1008, 475],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'LGd',
#    'graph_id': 1,
#    'graph_order': 662,
#    'id': 170,
#    'name': 'Dorsal part of the lateral geniculate complex',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864, 1008, 170],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'LP',
#    'graph_id': 1,
#    'graph_order': 668,
#    'id': 218,
#    'name': 'Lateral posterior nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 138, 218],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PO',
#    'graph_id': 1,
#    'graph_order': 669,
#    'id': 1020,
#    'name': 'Posterior complex of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 138, 1020],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'POL',
#    'graph_id': 1,
#    'graph_order': 670,
#    'id': 1029,
#    'name': 'Posterior limiting nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 138, 1029],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'SGN',
#    'graph_id': 1,
#    'graph_order': 671,
#    'id': 325,
#    'name': 'Suprageniculate nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 138, 325],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'AV',
#    'graph_id': 1,
#    'graph_order': 675,
#    'id': 255,
#    'name': 'Anteroventral nucleus of thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 255],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'AM',
#    'graph_id': 1,
#    'graph_order': 676,
#    'id': 127,
#    'name': 'Anteromedial nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 127],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'AD',
#    'graph_id': 1,
#    'graph_order': 679,
#    'id': 64,
#    'name': 'Anterodorsal nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 64],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'IAM',
#    'graph_id': 1,
#    'graph_order': 680,
#    'id': 1120,
#    'name': 'Interanteromedial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 1120],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'IAD',
#    'graph_id': 1,
#    'graph_order': 681,
#    'id': 1113,
#    'name': 'Interanterodorsal nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 1113],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'LD',
#    'graph_id': 1,
#    'graph_order': 682,
#    'id': 155,
#    'name': 'Lateral dorsal nucleus of thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 239, 155],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'IMD',
#    'graph_id': 1,
#    'graph_order': 684,
#    'id': 59,
#    'name': 'Intermediodorsal nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 444, 59],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'MD',
#    'graph_id': 1,
#    'graph_order': 685,
#    'id': 362,
#    'name': 'Mediodorsal nucleus of thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 444, 362],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'SMT',
#    'graph_id': 1,
#    'graph_order': 689,
#    'id': 366,
#    'name': 'Submedial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 444, 366],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PR',
#    'graph_id': 1,
#    'graph_order': 690,
#    'id': 1077,
#    'name': 'Perireunensis nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 444, 1077],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PVT',
#    'graph_id': 1,
#    'graph_order': 692,
#    'id': 149,
#    'name': 'Paraventricular nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 149],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PT',
#    'graph_id': 1,
#    'graph_order': 693,
#    'id': 15,
#    'name': 'Parataenial nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 15],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'RE',
#    'graph_id': 1,
#    'graph_order': 694,
#    'id': 181,
#    'name': 'Nucleus of reuniens',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 181],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'Xi',
#    'graph_id': 1,
#    'graph_order': 695,
#    'id': 560581559,
#    'name': 'Xiphoid thalamic nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 571, 560581559],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152363,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'RH',
#    'graph_id': 1,
#    'graph_order': 697,
#    'id': 189,
#    'name': 'Rhomboid nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 189],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'CM',
#    'graph_id': 1,
#    'graph_order': 698,
#    'id': 599,
#    'name': 'Central medial nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 599],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PCN',
#    'graph_id': 1,
#    'graph_order': 699,
#    'id': 907,
#    'name': 'Paracentral nucleus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 907],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'CL',
#    'graph_id': 1,
#    'graph_order': 700,
#    'id': 575,
#    'name': 'Central lateral nucleus of the thalamus',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856, 51, 575],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152363,
#     12,
#     184527634,
#     167587189],
# ...
#     10,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'GRN',
#    'graph_id': 1,
#    'graph_order': 975,
#    'id': 1048,
#    'name': 'Gigantocellular reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 1048],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'ICB',
#    'graph_id': 1,
#    'graph_order': 976,
#    'id': 372,
#    'name': 'Infracerebellar nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 372],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'IO',
#    'graph_id': 1,
#    'graph_order': 977,
#    'id': 83,
#    'name': 'Inferior olivary complex',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 83],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'IRN',
#    'graph_id': 1,
#    'graph_order': 978,
#    'id': 136,
#    'name': 'Intermediate reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 136],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     112905813,
#     167587189,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'ISN',
#    'graph_id': 1,
#    'graph_order': 979,
#    'id': 106,
#    'name': 'Inferior salivatory nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 106],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'LIN',
#    'graph_id': 1,
#    'graph_order': 980,
#    'id': 203,
#    'name': 'Linear nucleus of the medulla',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 203],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'LRN',
#    'graph_id': 1,
#    'graph_order': 981,
#    'id': 235,
#    'name': 'Lateral reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 235],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MARN',
#    'graph_id': 1,
#    'graph_order': 984,
#    'id': 307,
#    'name': 'Magnocellular reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 307],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MDRN',
#    'graph_id': 1,
#    'graph_order': 985,
#    'id': 395,
#    'name': 'Medullary reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 395],
#    'structure_set_ids': [112905828,
#     691663206,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MDRNd',
#    'graph_id': 1,
#    'graph_order': 986,
#    'id': 1098,
#    'name': 'Medullary reticular nucleus, dorsal part',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 395, 1098],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MDRNv',
#    'graph_id': 1,
#    'graph_order': 987,
#    'id': 1107,
#    'name': 'Medullary reticular nucleus, ventral part',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 395, 1107],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     112905813,
#     167587189,
#     114512892],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PARN',
#    'graph_id': 1,
#    'graph_order': 988,
#    'id': 852,
#    'name': 'Parvicellular reticular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 852],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PAS',
#    'graph_id': 1,
#    'graph_order': 989,
#    'id': 859,
#    'name': 'Parasolitary nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 859],
#    'structure_set_ids': [691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PGRNd',
#    'graph_id': 1,
#    'graph_order': 991,
#    'id': 970,
#    'name': 'Paragigantocellular reticular nucleus, dorsal part',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 938, 970],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PGRNl',
#    'graph_id': 1,
#    'graph_order': 992,
#    'id': 978,
#    'name': 'Paragigantocellular reticular nucleus, lateral part',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 938, 978],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'NR',
#    'graph_id': 1,
#    'graph_order': 995,
#    'id': 177,
#    'name': 'Nucleus of Roller',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 154, 177],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PRP',
#    'graph_id': 1,
#    'graph_order': 996,
#    'id': 169,
#    'name': 'Nucleus prepositus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 154, 169],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'PPY',
#    'graph_id': 1,
#    'graph_order': 998,
#    'id': 1069,
#    'name': 'Parapyramidal nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 1069],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'LAV',
#    'graph_id': 1,
#    'graph_order': 1002,
#    'id': 209,
#    'name': 'Lateral vestibular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 209],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MV',
#    'graph_id': 1,
#    'graph_order': 1003,
#    'id': 202,
#    'name': 'Medial vestibular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 202],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'SPIV',
#    'graph_id': 1,
#    'graph_order': 1004,
#    'id': 225,
#    'name': 'Spinal vestibular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 225],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'SUV',
#    'graph_id': 1,
#    'graph_order': 1005,
#    'id': 217,
#    'name': 'Superior vestibular nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 701, 217],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'x',
#    'graph_id': 1,
#    'graph_order': 1006,
#    'id': 765,
#    'name': 'Nucleus x',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 765],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'XII',
#    'graph_id': 1,
#    'graph_order': 1007,
#    'id': 773,
#    'name': 'Hypoglossal nucleus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 773],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     10,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'y',
#    'graph_id': 1,
#    'graph_order': 1008,
#    'id': 781,
#    'name': 'Nucleus y',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370, 781],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'RM',
#    'graph_id': 1,
#    'graph_order': 1011,
#    'id': 206,
#    'name': 'Nucleus raphe magnus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 379, 206],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 198, 226]},
#   {'acronym': 'RPA',
#    'graph_id': 1,
#    'graph_order': 1012,
#    'id': 230,
#    'name': 'Nucleus raphe pallidus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 379, 230],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 198, 226]},
#   {'acronym': 'RO',
#    'graph_id': 1,
#    'graph_order': 1013,
#    'id': 222,
#    'name': 'Nucleus raphe obscurus',
#    'structure_id_path': [997, 8, 343, 1065, 354, 379, 222],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152367,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 198, 226]},
#   {'acronym': 'LING',
#    'graph_id': 1,
#    'graph_order': 1020,
#    'id': 912,
#    'name': 'Lingula (I)',
#    'structure_id_path': [997, 8, 512, 528, 645, 912],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'CENT',
#    'graph_id': 1,
#    'graph_order': 1024,
#    'id': 920,
#    'name': 'Central lobule',
#    'structure_id_path': [997, 8, 512, 528, 645, 920],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'CUL',
#    'graph_id': 1,
#    'graph_order': 1033,
#    'id': 928,
#    'name': 'Culmen',
#    'structure_id_path': [997, 8, 512, 528, 645, 928],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'DEC',
#    'graph_id': 1,
#    'graph_order': 1046,
#    'id': 936,
#    'name': 'Declive (VI)',
#    'structure_id_path': [997, 8, 512, 528, 645, 936],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'FOTU',
#    'graph_id': 1,
#    'graph_order': 1050,
#    'id': 944,
#    'name': 'Folium-tuber vermis (VII)',
#    'structure_id_path': [997, 8, 512, 528, 645, 944],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'PYR',
#    'graph_id': 1,
#    'graph_order': 1054,
#    'id': 951,
#    'name': 'Pyramus (VIII)',
#    'structure_id_path': [997, 8, 512, 528, 645, 951],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'UVU',
#    'graph_id': 1,
#    'graph_order': 1058,
#    'id': 957,
#    'name': 'Uvula (IX)',
#    'structure_id_path': [997, 8, 512, 528, 645, 957],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'NOD',
#    'graph_id': 1,
#    'graph_order': 1062,
#    'id': 968,
#    'name': 'Nodulus (X)',
#    'structure_id_path': [997, 8, 512, 528, 645, 968],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'SIM',
#    'graph_id': 1,
#    'graph_order': 1067,
#    'id': 1007,
#    'name': 'Simple lobule',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1007],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'AN',
#    'graph_id': 1,
#    'graph_order': 1071,
#    'id': 1017,
#    'name': 'Ansiform lobule',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1017],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'PRM',
#    'graph_id': 1,
#    'graph_order': 1080,
#    'id': 1025,
#    'name': 'Paramedian lobule',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1025],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'COPY',
#    'graph_id': 1,
#    'graph_order': 1084,
#    'id': 1033,
#    'name': 'Copula pyramidis',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1033],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'PFL',
#    'graph_id': 1,
#    'graph_order': 1088,
#    'id': 1041,
#    'name': 'Paraflocculus',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1041],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'FL',
#    'graph_id': 1,
#    'graph_order': 1092,
#    'id': 1049,
#    'name': 'Flocculus',
#    'structure_id_path': [997, 8, 512, 528, 1073, 1049],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'FN',
#    'graph_id': 1,
#    'graph_order': 1097,
#    'id': 989,
#    'name': 'Fastigial nucleus',
#    'structure_id_path': [997, 8, 512, 519, 989],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 253, 188]},
#   {'acronym': 'IP',
#    'graph_id': 1,
#    'graph_order': 1098,
#    'id': 91,
#    'name': 'Interposed nucleus',
#    'structure_id_path': [997, 8, 512, 519, 91],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 253, 188]},
#   {'acronym': 'DN',
#    'graph_id': 1,
#    'graph_order': 1099,
#    'id': 846,
#    'name': 'Dentate nucleus',
#    'structure_id_path': [997, 8, 512, 519, 846],
#    'structure_set_ids': [112905828,
#     691663206,
#     687527945,
#     12,
#     688152368,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [255, 253, 188]},
#   {'acronym': 'VeCB',
#    'graph_id': 1,
#    'graph_order': 1100,
#    'id': 589508455,
#    'name': 'Vestibulocerebellar nucleus',
#    'structure_id_path': [997, 8, 512, 519, 589508455],
#    'structure_set_ids': [112905828,
#     691663206,
#     688152368,
#     184527634,
#     167587189],
#    'rgb_triplet': [255, 253, 188]},
#   {'acronym': 'fiber tracts',
#    'graph_id': 1,
#    'graph_order': 1101,
#    'id': 1009,
#    'name': 'fiber tracts',
#    'structure_id_path': [997, 1009],
#    'structure_set_ids': [687527945, 184527634, 167587189, 691663206],
#    'rgb_triplet': [204, 204, 204]}])

# %%
default_structures_new = default_structures.copy()

# %%
ds_id_new = [default_structures_new[i]['id'] for i in range(len(default_structures_new))]

ds_id_old = [default_structures_old[i]['id'] for i in range(len(default_structures_old))]

# %%
len(np.intersect1d(ds_id_new, ds_id_old))
# Out:
# 292

# %%
new_id = np.setdiff1d(ds_id_new,ds_id_old)
old_id = np.setdiff1d(ds_id_old,ds_id_new)

# %%
old_id
# Out:
# array([934])

# %%
ia_map[934]
# Out:
# 'ENTmv'

# %%
[ia_map[i] for i in new_id],new_id
# Out:
# (['MT',
#   'DT',
#   'MDRN',
#   'ME',
#   'ProS',
#   'APr',
#   'MA3',
#   'P5',
#   'Acs5',
#   'PC5',
#   'I5',
#   'Xi',
#   'PIL',
#   'PoT',
#   'IntG',
#   'VMPO',
#   'PeF',
#   'HATA',
#   'Pa5',
#   'VeCB',
#   'SCO',
#   'PDTg',
#   'Pa4',
#   'PN'],
#  array([       58,        75,       395,     10671, 484682470, 484682508,
#         549009211, 549009215, 549009219, 549009223, 549009227, 560581559,
#         560581563, 563807435, 563807439, 576073699, 576073704, 589508447,
#         589508451, 589508455, 599626923, 599626927, 606826663, 607344830]))

# %%
COARSE_STRUCTURE_SET_ID = 3#2#167587189#3#2(old)
DEFAULT_STRUCTURE_SET_IDS = tuple([COARSE_STRUCTURE_SET_ID])
tree = cache.get_structure_tree()
default_structures = tree.get_structures_by_set_id(DEFAULT_STRUCTURE_SET_IDS)
print(len(default_structures)), default_structures
# Out:
# 51
# (None,
#  [{'acronym': 'FRP',
#    'graph_id': 1,
#    'graph_order': 6,
#    'id': 184,
#    'name': 'Frontal pole, cerebral cortex',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 184],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     112905813,
#     114512891],
#    'rgb_triplet': [38, 143, 69]},
#   {'acronym': 'MO',
#    'graph_id': 1,
#    'graph_order': 12,
#    'id': 500,
#    'name': 'Somatomotor areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 500],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [31, 157, 90]},
#   {'acronym': 'SS',
#    'graph_id': 1,
#    'graph_order': 30,
#    'id': 453,
#    'name': 'Somatosensory areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 453],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     10,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [24, 128, 100]},
#   {'acronym': 'GU',
#    'graph_id': 1,
#    'graph_order': 107,
#    'id': 1057,
#    'name': 'Gustatory areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 1057],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [0, 156, 117]},
#   {'acronym': 'VISC',
#    'graph_id': 1,
#    'graph_order': 114,
#    'id': 677,
#    'name': 'Visceral area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 677],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [17, 173, 131]},
#   {'acronym': 'AUD',
#    'graph_id': 1,
#    'graph_order': 121,
#    'id': 247,
#    'name': 'Auditory areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 247],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [1, 147, 153]},
#   {'acronym': 'VIS',
#    'graph_id': 1,
#    'graph_order': 157,
#    'id': 669,
#    'name': 'Visual areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 669],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [8, 133, 140]},
#   {'acronym': 'ACA',
#    'graph_id': 1,
#    'graph_order': 220,
#    'id': 31,
#    'name': 'Anterior cingulate area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 31],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [64, 166, 102]},
#   {'acronym': 'PL',
#    'graph_id': 1,
#    'graph_order': 238,
#    'id': 972,
#    'name': 'Prelimbic area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 972],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [47, 168, 80]},
#   {'acronym': 'ILA',
#    'graph_id': 1,
#    'graph_order': 245,
#    'id': 44,
#    'name': 'Infralimbic area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 44],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [89, 179, 99]},
#   {'acronym': 'ORB',
#    'graph_id': 1,
#    'graph_order': 252,
#    'id': 714,
#    'name': 'Orbital area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 714],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [36, 138, 94]},
#   {'acronym': 'AI',
#    'graph_id': 1,
#    'graph_order': 278,
#    'id': 95,
#    'name': 'Agranular insular area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 95],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [33, 152, 102]},
#   {'acronym': 'RSP',
#    'graph_id': 1,
#    'graph_order': 297,
#    'id': 254,
#    'name': 'Retrosplenial area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 254],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     10,
#     12,
#     184527634,
#     112905813,
#     114512891],
#    'rgb_triplet': [26, 166, 152]},
#   {'acronym': 'PTLp',
#    'graph_id': 1,
#    'graph_order': 339,
#    'id': 22,
#    'name': 'Posterior parietal association areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 22],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891],
#    'rgb_triplet': [0, 159, 172]},
#   {'acronym': 'TEa',
#    'graph_id': 1,
#    'graph_order': 360,
#    'id': 541,
#    'name': 'Temporal association areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 541],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [21, 176, 179]},
#   {'acronym': 'PERI',
#    'graph_id': 1,
#    'graph_order': 367,
#    'id': 922,
#    'name': 'Perirhinal area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 922],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [14, 150, 132]},
#   {'acronym': 'ECT',
#    'graph_id': 1,
#    'graph_order': 373,
#    'id': 895,
#    'name': 'Ectorhinal area',
#    'structure_id_path': [997, 8, 567, 688, 695, 315, 895],
#    'structure_set_ids': [3,
#     112905828,
#     688152357,
#     691663206,
#     687527945,
#     12,
#     184527634,
#     167587189,
#     114512891],
#    'rgb_triplet': [13, 159, 145]},
#   {'acronym': 'OLF',
#    'graph_id': 1,
#    'graph_order': 379,
#    'id': 698,
#    'name': 'Olfactory areas',
#    'structure_id_path': [997, 8, 567, 688, 695, 698],
#    'structure_set_ids': [2,
#     3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     687527670,
#     114512891,
#     114512892],
#    'rgb_triplet': [154, 210, 189]},
#   {'acronym': 'CA',
#    'graph_id': 1,
#    'graph_order': 456,
#    'id': 375,
#    'name': "Ammon's horn",
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 375],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'DG',
#    'graph_id': 1,
#    'graph_order': 473,
#    'id': 726,
#    'name': 'Dentate gyrus',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 726],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     688152359,
#     687527945,
#     10,
#     12,
#     184527634,
#     112905813,
#     167587189,
#     114512891],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'FC',
#    'graph_id': 1,
#    'graph_order': 490,
#    'id': 982,
#    'name': 'Fasciola cinerea',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 982],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'IG',
#    'graph_id': 1,
#    'graph_order': 491,
#    'id': 19,
#    'name': 'Induseum griseum',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 1080, 19],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     688152359,
#     687527945,
#     12,
#     184527634,
#     167587189],
#    'rgb_triplet': [126, 208, 75]},
#   {'acronym': 'RHP',
#    'graph_id': 1,
#    'graph_order': 492,
#    'id': 822,
#    'name': 'Retrohippocampal region',
#    'structure_id_path': [997, 8, 567, 688, 695, 1089, 822],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [50, 184, 37]},
#   {'acronym': 'CTXsp',
#    'graph_id': 1,
#    'graph_order': 555,
#    'id': 703,
#    'name': 'Cortical subplate',
#    'structure_id_path': [997, 8, 567, 688, 703],
#    'structure_set_ids': [2,
#     3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     687527670,
#     114512891],
#    'rgb_triplet': [138, 218, 135]},
#   {'acronym': 'STRd',
#    'graph_id': 1,
#    'graph_order': 572,
#    'id': 485,
#    'name': 'Striatum dorsal region',
#    'structure_id_path': [997, 8, 567, 623, 477, 485],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [152, 214, 249]},
#   {'acronym': 'STRv',
#    'graph_id': 1,
#    'graph_order': 574,
#    'id': 493,
#    'name': 'Striatum ventral region',
#    'structure_id_path': [997, 8, 567, 623, 477, 493],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [128, 205, 248]},
#   {'acronym': 'LSX',
#    'graph_id': 1,
#    'graph_order': 585,
#    'id': 275,
#    'name': 'Lateral septal complex',
#    'structure_id_path': [997, 8, 567, 623, 477, 275],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [144, 203, 237]},
#   {'acronym': 'sAMY',
#    'graph_id': 1,
#    'graph_order': 592,
#    'id': 278,
#    'name': 'Striatum-like amygdalar nuclei',
#    'structure_id_path': [997, 8, 567, 623, 477, 278],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891],
#    'rgb_triplet': [128, 192, 226]},
#   {'acronym': 'PALd',
#    'graph_id': 1,
#    'graph_order': 609,
#    'id': 818,
#    'name': 'Pallidum, dorsal region',
#    'structure_id_path': [997, 8, 567, 623, 803, 818],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [133, 153, 204]},
#   {'acronym': 'PALv',
#    'graph_id': 1,
#    'graph_order': 612,
#    'id': 835,
#    'name': 'Pallidum, ventral region',
#    'structure_id_path': [997, 8, 567, 623, 803, 835],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [162, 177, 216]},
#   {'acronym': 'PALm',
#    'graph_id': 1,
#    'graph_order': 615,
#    'id': 826,
#    'name': 'Pallidum, medial region',
#    'structure_id_path': [997, 8, 567, 623, 803, 826],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891],
#    'rgb_triplet': [150, 167, 211]},
#   {'acronym': 'PALc',
#    'graph_id': 1,
#    'graph_order': 620,
#    'id': 809,
#    'name': 'Pallidum, caudal region',
#    'structure_id_path': [997, 8, 567, 623, 803, 809],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [179, 192, 223]},
#   {'acronym': 'DORsm',
#    'graph_id': 1,
#    'graph_order': 642,
#    'id': 864,
#    'name': 'Thalamus, sensory-motor cortex related',
#    'structure_id_path': [997, 8, 343, 1129, 549, 864],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 128, 132]},
#   {'acronym': 'DORpm',
#    'graph_id': 1,
#    'graph_order': 666,
#    'id': 856,
#    'name': 'Thalamus, polymodal association cortex related',
#    'structure_id_path': [997, 8, 343, 1129, 549, 856],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 144, 159]},
#   {'acronym': 'PVZ',
#    'graph_id': 1,
#    'graph_order': 716,
#    'id': 157,
#    'name': 'Periventricular zone',
#    'structure_id_path': [997, 8, 343, 1129, 1097, 157],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [255, 93, 80]},
#   {'acronym': 'PVR',
#    'graph_id': 1,
#    'graph_order': 734,
#    'id': 141,
#    'name': 'Periventricular region',
#    'structure_id_path': [997, 8, 343, 1129, 1097, 141],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [255, 85, 71]},
#   {'acronym': 'MEZ',
#    'graph_id': 1,
#    'graph_order': 756,
#    'id': 467,
#    'name': 'Hypothalamic medial zone',
#    'structure_id_path': [997, 8, 343, 1129, 1097, 467],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [255, 76, 62]},
#   {'acronym': 'LZ',
#    'graph_id': 1,
#    'graph_order': 793,
#    'id': 290,
#    'name': 'Hypothalamic lateral zone',
#    'structure_id_path': [997, 8, 343, 1129, 1097, 290],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [242, 72, 59]},
#   {'acronym': 'ME',
#    'graph_id': 1,
#    'graph_order': 805,
#    'id': 10671,
#    'name': 'Median eminence',
#    'structure_id_path': [997, 8, 343, 1129, 1097, 10671],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     688152364,
#     184527634,
#     167587189],
#    'rgb_triplet': [242, 72, 59]},
#   {'acronym': 'MBsen',
#    'graph_id': 1,
#    'graph_order': 807,
#    'id': 339,
#    'name': 'Midbrain, sensory related',
#    'structure_id_path': [997, 8, 343, 313, 339],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 122, 255]},
#   {'acronym': 'MBmot',
#    'graph_id': 1,
#    'graph_order': 821,
#    'id': 323,
#    'name': 'Midbrain, motor related',
#    'structure_id_path': [997, 8, 343, 313, 323],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 144, 255]},
#   {'acronym': 'MBsta',
#    'graph_id': 1,
#    'graph_order': 865,
#    'id': 348,
#    'name': 'Midbrain, behavioral state related',
#    'structure_id_path': [997, 8, 343, 313, 348],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 144, 255]},
#   {'acronym': 'P-sen',
#    'graph_id': 1,
#    'graph_order': 884,
#    'id': 1132,
#    'name': 'Pons, sensory related',
#    'structure_id_path': [997, 8, 343, 1065, 771, 1132],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 174, 111]},
#   {'acronym': 'P-mot',
#    'graph_id': 1,
#    'graph_order': 906,
#    'id': 987,
#    'name': 'Pons, motor related',
#    'structure_id_path': [997, 8, 343, 1065, 771, 987],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 186, 134]},
#   {'acronym': 'P-sat',
#    'graph_id': 1,
#    'graph_order': 924,
#    'id': 1117,
#    'name': 'Pons, behavioral state related',
#    'structure_id_path': [997, 8, 343, 1065, 771, 1117],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [255, 195, 149]},
#   {'acronym': 'MY-sen',
#    'graph_id': 1,
#    'graph_order': 936,
#    'id': 386,
#    'name': 'Medulla, sensory related',
#    'structure_id_path': [997, 8, 343, 1065, 354, 386],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [255, 165, 210]},
#   {'acronym': 'MY-mot',
#    'graph_id': 1,
#    'graph_order': 964,
#    'id': 370,
#    'name': 'Medulla, motor related',
#    'structure_id_path': [997, 8, 343, 1065, 354, 370],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 179, 217]},
#   {'acronym': 'MY-sat',
#    'graph_id': 1,
#    'graph_order': 1010,
#    'id': 379,
#    'name': 'Medulla, behavioral state related',
#    'structure_id_path': [997, 8, 343, 1065, 354, 379],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [255, 198, 226]},
#   {'acronym': 'VERM',
#    'graph_id': 1,
#    'graph_order': 1019,
#    'id': 645,
#    'name': 'Vermal regions',
#    'structure_id_path': [997, 8, 512, 528, 645],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     12,
#     184527634,
#     112905813,
#     114512891,
#     114512892],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'HEM',
#    'graph_id': 1,
#    'graph_order': 1066,
#    'id': 1073,
#    'name': 'Hemispheric regions',
#    'structure_id_path': [997, 8, 512, 528, 1073],
#    'structure_set_ids': [3, 112905828, 691663206, 12, 184527634, 114512891],
#    'rgb_triplet': [255, 252, 145]},
#   {'acronym': 'CBN',
#    'graph_id': 1,
#    'graph_order': 1096,
#    'id': 519,
#    'name': 'Cerebellar nuclei',
#    'structure_id_path': [997, 8, 512, 519],
#    'structure_set_ids': [3,
#     112905828,
#     691663206,
#     10,
#     12,
#     184527634,
#     114512891],
#    'rgb_triplet': [240, 240, 128]}])

# %%
data_info['primary-injection-structure']
# Out:
# (2875,)

# %%
np.isin(ds_id_old , info['primary_injection_structure'])[0]
# Out:
# True

# %%
len(np.where(np.isin(info['primary_injection_structure'],ds_id_new ))[0])
# Out:
# 1751

# %%
len(np.where(np.isin(info['primary_injection_structure'],ds_id_old ))[0])
# Out:
# 1745

# %%
#.shape
len(np.where(np.isin(info['primary_injection_structure'],ontological_order ))[0])
# Out:
# 1745

# %%
#experiments_minor_structures_sid = experiments_minor_structures[sid]
def get_summary_structure(structure_data):
    
    structure_data
    #nexp = len(experiments_minor_structures_sid)
    minors = [ai_map[ms] for ms in experiments_minor_structures_sid]
    leaves = [st.child_ids([minors[i]]) for i in range(len(minors))]
    minor_structures = np.zeros(nexp)
    for i in range(nexp):
        print(i)
        exp = msvd.experiments[list(msvd.experiments.keys())[i]]
        if len(leaves[i][0]) > 0:
            #print(i)
            nebdist = np.zeros(len(leaves[i][0]))
            for j in range(len(leaves[i][0])):
                #print(j)
                #print(leaves[i][0][j])
                m = Mask.from_cache(cache,structure_ids=[leaves[i][0][j]],hemisphere_id=3)
                try:
                    nebdist[j] = np.linalg.norm(exp.centroid - m.coordinates, axis = 1).min()
                except Exception:
                    pass
                #print(m.coordinates)
                #print(nebdist)
                #nebdist[j] = np.linalg.norm(exp.centroid - m.coordinates, axis = 1).min()
            nebdist[np.where(nebdist == 0.)[0]] = 1000
            nearestneb = nebdist.argmin()
            if nebdist.min() != 1000:
                minor_structures[i] = leaves[i][0][nearestneb]
            else: 
                minor_structures[i] = minors[i]
        else:
            minor_structures[i] = minors[i]
    return(np.asarray(minor_structures, dtype = int))

# %%
experiments_minor_structures_sid = experiments_minor_structures[sid]
def get_leaf_structure(msvd, experiments_minor_structures_sid):
    
    nexp = len(experiments_minor_structures_sid)
    minors = [ai_map[ms] for ms in experiments_minor_structures_sid]
    leaves = [st.child_ids([minors[i]]) for i in range(len(minors))]
    minor_structures = np.zeros(nexp)
    for i in range(nexp):
        print(i)
        exp = msvd.experiments[list(msvd.experiments.keys())[i]]
        if len(leaves[i][0]) > 0:
            #print(i)
            nebdist = np.zeros(len(leaves[i][0]))
            for j in range(len(leaves[i][0])):
                #print(j)
                #print(leaves[i][0][j])
                m = Mask.from_cache(cache,structure_ids=[leaves[i][0][j]],hemisphere_id=3)
                try:
                    nebdist[j] = np.linalg.norm(exp.centroid - m.coordinates, axis = 1).min()
                except Exception:
                    pass
                #print(m.coordinates)
                #print(nebdist)
                #nebdist[j] = np.linalg.norm(exp.centroid - m.coordinates, axis = 1).min()
            nebdist[np.where(nebdist == 0.)[0]] = 1000
            nearestneb = nebdist.argmin()
            if nebdist.min() != 1000:
                minor_structures[i] = leaves[i][0][nearestneb]
            else: 
                minor_structures[i] = minors[i]
        else:
            minor_structures[i] = minors[i]
    return(np.asarray(minor_structures, dtype = int))

# %%
#connectivity_data.structure_datas[315].eids

# %%
cache.get_experiment_structure_unionizes(159832064).shape
# Out:
# (2548, 19)

# %%
cache.get_experiment_structure_unionizes(159832064).iloc[:5]
# Out:
#    hemisphere_id         id  is_injection  max_voxel_density  max_voxel_x  \
# 0              3  628243119         False           0.000000            0
# 1              1  628239030         False           0.000000            0
# 2              3  628243224         False           0.697898         5710
# 3              3  628244185         False           0.625754         6460
# 4              2  628236463         False           0.984967         6850
#
#    max_voxel_y  max_voxel_z  normalized_projection_volume  projection_density  \
# 0            0            0                      0.000000            0.000000
# 1            0            0                      0.000000            0.000000
# 2         6220         7170                      0.012065            0.003072
# 3         5410         8120                      0.004168            0.000451
# 4         4530         8110                      0.983053            0.075864
#
#    projection_energy  projection_intensity  projection_volume  experiment_id  \
# 0           0.000000              0.000000           0.000000      159832064
# 1           0.000000              0.000000           0.000000      159832064
# 2           3.014907            981.354163           0.001897      159832064
# 3           0.530254           1175.085737           0.000655      159832064
# 4         137.787430           1816.247925           0.154537      159832064
#
#    structure_id  sum_pixel_intensity    sum_pixels  \
# 0           187         1.230172e+11  4.907862e+08
# 1           903         1.177789e+10  9.212580e+07
# 2           226         9.819268e+10  5.039784e+08
# 3           536         2.745102e+11  1.185300e+09
# 4           784         3.834216e+11  1.662886e+09
#
#    sum_projection_pixel_intensity  sum_projection_pixels    volume
# 0                    0.000000e+00           0.000000e+00  0.601213
# 1                    0.000000e+00           0.000000e+00  0.112854
# 2                    1.519448e+09           1.548318e+06  0.617374
# 3                    6.285105e+08           5.348636e+05  1.451992
# 4                    2.291248e+11           1.261528e+08  2.037035

# %%
cache.get_experiments(dataframe= [628243119]).shape
# Out:
# (1751, 15)

# %%
info = cache.get_experiments(dataframe= [628236463])

# %%
cache = VoxelModelCache(manifest_file=manifest_file,ccf_version  = 167587189)
a= cache.get_experiments(520336173)['primary_injection_structure']

# %%
cache = VoxelModelCache(manifest_file=manifest_file,ccf_version  = 687527945)
b= cache.get_experiments(520336173)['primary_injection_structure']

# %%
(a - b).min()
# Out:
# 0

# %%
cache.get_experiments(520336173)['primary_injection_structure']
# Out:
# id
# 301875966     574
# 520336173       1
# 177904363     136
# 602828622     993
# 178489574     475
#              ...
# 126860974     731
# 114400640    1039
# 112791318     337
# 156545918     385
# 308027576     879
# Name: primary_injection_structure, Length: 1751, dtype: int64

# %%
help(cache.get_experiment_structure_unionizes)
# Out:
# Help on method get_experiment_structure_unionizes in module allensdk.core.mouse_connectivity_cache:
#
# get_experiment_structure_unionizes(experiment_id, file_name=None, is_injection=None, structure_ids=None, include_descendants=False, hemisphere_ids=None) method of mcmodels.core.voxel_model_cache.VoxelModelCache instance
#     Retrieve the structure unionize data for a specific experiment.  Filter by
#     structure, injection status, and hemisphere.
#
#     Parameters
#     ----------
#
#     experiment_id: int
#         ID of the experiment of interest.  Corresponds to section_data_set_id in the API.
#
#     file_name: string
#         File name to save/read the experiments list.  If file_name is None,
#         the file_name will be pulled out of the manifest.  If caching
#         is disabled, no file will be saved. Default is None.
#
#     is_injection: boolean
#         If True, only return unionize records that disregard non-injection pixels.
#         If False, only return unionize records that disregard injection pixels.
#         If None, return all records.  Default None.
#
#     structure_ids: list
#         Only return unionize records for a specific set of structures.
#         If None, return all records. Default None.
#
#     include_descendants: boolean
#         Include all descendant records for specified structures. Default False.
#
#     hemisphere_ids: list
#         Only return unionize records that disregard pixels outside of a hemisphere.
#         or set of hemispheres. Left = 1, Right = 2, Both = 3.  If None, include all
#         records [1, 2, 3].  Default None.
